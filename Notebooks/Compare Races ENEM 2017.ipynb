# %% [markdown]
# # Compare Races - ENEM 2017

# %%
import pandas as pd
from CompareGroupsFunctions import *

ano = '2017'

# %% [markdown]
# ## 1. Ciências Humanas

# %%
ch_comp = GroupComparator(comp='CH', ano=ano, gps=[0, 1, 2, 3])
df_gp = ch_comp.get_df_gp()
ch_comp.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 524.93;   Std: 89.09
# Branca - Média: 537.03;   Std: 83.34
# Preta - Média: 502.97;   Std: 77.78
# Parda - Média: 501.83;   Std: 79.63
# Geral - Média: 516.72;   Std: 82.96

# %%
ch_comp.plot_hist_scores()

# %%
bin_ch = ch_comp.bin_scores()
auc_ch = ch_comp.auc_groups()

auc_ch
# Out:
#                     0          1          2          3      Geral
# Item 44604   8.383234   8.458251   8.245734   8.361414   8.403868
# Item 38250  11.372430  11.315543  11.452390  11.282713  11.306589
# Item 43284   4.848816   4.717016   4.739278   4.780473   4.749686
# Item 81598  10.463640  10.353451  10.474237  10.485626  10.425017
# Item 8172   10.502395  10.213905  10.692034  10.372661  10.331878
# Item 49683  11.804548  12.038029  12.407804  12.092952  12.087094
# Item 82228   9.558886   9.255323   9.450679   9.301509   9.302087
# Item 45306   4.627667   4.545835   4.489680   4.655876   4.595475
# Item 84226   8.686088   8.584125   8.434281   8.519987   8.526808
# Item 83848   9.176798   9.326895   9.344510   9.398021   9.303670
# Item 84165   8.446320   8.491499   8.615426   8.624779   8.563719
# Item 84192   6.560586   6.425438   6.408811   6.238783   6.359039
# Item 20109  12.129944  12.329348  12.208968  12.203284  12.258597
# Item 81916   7.488682   7.699483   7.207635   7.447119   7.601242
# Item 82451   9.504711   9.350085   9.611048   9.611501   9.483246
# Item 31360  10.524191  10.517711  10.576373  10.628888  10.558220
# Item 78146   9.051979   9.187045   9.132810   9.115778   9.145215
# Item 25316   9.090186   9.225450   8.928204   9.085898   9.150279
# Item 67329   7.330013   7.411330   7.392396   7.400693   7.428348
# Item 96575   8.413642   8.441759   8.386040   8.399288   8.406438
# Item 66214   5.695852   5.729913   5.445101   5.623115   5.665147
# Item 75940   9.006648   9.141200   8.942181   9.161271   9.150104
# Item 84128   4.266103   4.237779   4.401358   4.539214   4.376411
# Item 6990    5.914717   5.762145   5.735908   5.868741   5.794414
# Item 43294   5.947465   5.859202   5.653822   5.770618   5.841282
# Item 76970   9.969562  10.000718   9.668695   9.839127   9.897463
# Item 79027  10.097145   9.968756  10.003598  10.182276  10.074287
# Item 67012   7.878863   7.956179   8.035688   8.115894   8.024097
# Item 47012   8.314358   8.225139   8.653884   8.482098   8.340755
# Item 37521   5.077261   4.939023   4.904386   4.916574   4.953706
# Item 29085   9.112523   9.078721   9.433728   9.134342   9.091798
# Item 8456    8.800572   8.950336   8.594722   8.744390   8.833827
# Item 25281  11.502917  11.620519  11.595319  11.586251  11.591974
# Item 83836   5.811362   5.737557   5.858342   5.779983   5.768779
# Item 30150   8.859538   8.540946   8.677342   8.651031   8.620147
# Item 82449   5.353570   5.709277   5.542174   5.582684   5.659287
# Item 7962    5.943237   6.035250   6.258240   6.220337   6.125499
# Item 24935   5.352100   5.206280   5.550204   5.403100   5.306891
# Item 27214  10.261847  10.343164  10.340163  10.356091  10.333905
# Item 47840   6.405147   6.348295   6.253142   6.262826   6.328645
# Item 18647  11.042228  11.250157  10.747300  10.895136  11.040971
# Item 79005   9.226838   9.479291   8.938528   9.077066   9.273310
# Item 24918   8.155638   8.163838   8.385148   8.295798   8.237079
# Item 23043   4.741934   4.632079   4.468007   4.438186   4.574556
# Item 49661   2.747741   2.584836   2.694764   2.600625   2.586465

# %%
sorted_auc_dif_ch = ch_comp.sort_abs_auc_dif()
# Out:
# Item 96575    0.055719
# Item 31360    0.070667
# Item 27214    0.081317
# Item 67329    0.081317
# Item 67012    0.091797
# Item 47840    0.095152
# Item 25281    0.117602
# Item 83836    0.120786
# Item 81598    0.120787
# Item 84165    0.123926
# Item 43284    0.131800
# Item 78146    0.135067
# Item 37521    0.138239
# Item 84226    0.149844
# Item 83848    0.150097
# Item 6990     0.152572
# Item 49661    0.162905
# Item 84128    0.163579
# Item 23043    0.164072
# Item 45306    0.166195
# Item 38250    0.169677
# Item 84192    0.170028
# Item 79027    0.178678
# Item 20109    0.199404
# Item 43294    0.205380
# Item 44604    0.212518
# Item 75940    0.219090
# Item 24918    0.221310
# Item 7962     0.222990
# Item 82451    0.260963
# Item 66214    0.284812
# Item 25316    0.297246
# Item 82228    0.303563
# Item 30150    0.318592
# Item 76970    0.332023
# Item 24935    0.343923
# Item 29085    0.355007
# Item 8456     0.355613
# Item 82449    0.355707
# Item 49683    0.369774
# Item 47012    0.428745
# Item 8172     0.478129
# Item 81916    0.491848
# Item 18647    0.502856
# Item 79005    0.540764
# dtype: float64

# %%
ch_comp.plot_item_compar(item = 'Item 79005')

# %%
ch_comp.plot_item_compar(item = 'Item 18647')

# %% [markdown]
# ## 2. Ciências da Natureza

# %%
cn_comp = GroupComparator(comp='CN', ano=ano, gps=[0, 1, 2, 3])
df_gp = cn_comp.get_df_gp()
cn_comp.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 517.18;   Std: 78.62
# Branca - Média: 525.88;   Std: 75.60
# Preta - Média: 494.36;   Std: 65.06
# Parda - Média: 495.92;   Std: 67.21
# Geral - Média: 508.43;   Std: 72.35

# %%
cn_comp.plot_hist_scores()

# %%
bin_cn = cn_comp.bin_scores()
auc_cn = cn_comp.auc_groups()

auc_cn
# Out:
#                     0          1          2          3      Geral
# Item 29460   5.247514   5.199784   5.081390   5.146824   5.224147
# Item 59980   7.751332   7.557018   7.750169   7.690580   7.614859
# Item 81339   7.216672   7.326768   6.981026   7.271417   7.296327
# Item 81944   9.856572   9.829038   9.815942   9.816173   9.801564
# Item 43722   4.874846   4.817515   4.712432   4.723085   4.787879
# Item 89981   8.011028   8.115290   7.773658   8.119547   8.104030
# Item 40150   7.073019   6.822593   7.104385   6.993271   6.867616
# Item 47418   5.262599   5.294030   5.175709   5.439821   5.337879
# Item 83923  11.256585  11.332786  10.869369  11.064917  11.208237
# Item 42006  10.130821  10.355083  10.291333  10.071482  10.211793
# Item 81968  10.906784  10.921687  10.765573  10.887852  10.871138
# Item 56286   3.029685   2.880382   3.048127   3.080093   2.964907
# Item 84291   3.969656   3.831438   3.719354   3.803806   3.836846
# Item 62247   6.931770   7.189504   6.774477   6.933651   7.067691
# Item 76032   9.331680   9.445860   9.337832   9.431985   9.426680
# Item 87974   1.940483   1.716393   1.866031   1.816330   1.757442
# Item 81971  10.046634  10.161782   9.827819   9.857572  10.005083
# Item 59829   2.916287   2.839779   2.761660   2.864919   2.871376
# Item 49555   8.225626   8.128335   8.141891   8.106935   8.136663
# Item 64059   7.739025   7.764909   7.761699   7.705386   7.702753
# Item 26843   7.905563   7.826576   7.776068   7.880150   7.869673
# Item 78598   4.413656   4.396579   4.208274   4.353179   4.392169
# Item 60582   3.556496   3.424511   3.743704   3.421138   3.444910
# Item 11590   5.587834   5.768861   5.539691   5.730483   5.734883
# Item 23921  10.381855  10.316783  10.468609  10.414781  10.361685
# Item 66897   4.998320   4.782021   5.225783   5.086353   4.917154
# Item 88958   4.776780   4.698908   4.741636   4.729371   4.727838
# Item 84223  10.978460  11.038722  10.780544  10.711036  10.852110
# Item 68394   3.712805   3.690394   3.784550   3.785191   3.742978
# Item 18349   6.296319   6.286179   6.450723   6.534379   6.419810
# Item 82421   4.498572   4.466616   4.317046   4.450106   4.474045
# Item 30022   6.572178   6.761022   6.708687   6.619994   6.671922
# Item 42557   5.208937   5.286259   5.059960   4.917336   5.145607
# Item 88873   5.057085   4.924166   4.903910   4.916747   4.947642
# Item 61269   8.585206   8.559817   8.570898   8.553565   8.585533
# Item 81780   9.065514   9.261487   9.127739   9.059953   9.141481
# Item 43703   4.768699   4.861471   4.856254   4.864809   4.884077
# Item 18231   8.208727   7.963938   8.188282   8.127668   8.055029
# Item 11793   4.295903   4.470002   4.372615   4.513018   4.503192
# Item 60699   8.282752   8.323682   8.251247   8.312882   8.308600
# Item 43880   2.147955   2.068190   2.081952   2.124400   2.127621
# Item 8757   11.496454  11.246114  11.628389  11.533186  11.427106
# Item 48655   4.179147   4.013524   3.954586   4.092213   4.040705
# Item 17983   6.282513   6.486302   6.317903   6.358090   6.430219
# Item 48663   6.836290   6.599884   6.935177   6.752401   6.648690

# %%
sorted_auc_dif_cn = cn_comp.sort_abs_auc_dif()
# Out:
# Item 81944    0.027535
# Item 61269    0.031968
# Item 64059    0.056314
# Item 60699    0.072435
# Item 88958    0.077872
# Item 43880    0.079765
# Item 43703    0.092772
# Item 68394    0.094157
# Item 49555    0.097291
# Item 59829    0.103259
# Item 26843    0.104081
# Item 43722    0.105083
# Item 76032    0.114180
# Item 29460    0.118393
# Item 88873    0.132919
# Item 84291    0.138218
# Item 82421    0.149571
# Item 23921    0.151826
# Item 81968    0.156114
# Item 18349    0.164544
# Item 48655    0.165622
# Item 56286    0.167746
# Item 11793    0.174099
# Item 78598    0.188305
# Item 30022    0.188844
# Item 59980    0.194314
# Item 81780    0.195973
# Item 17983    0.203788
# Item 87974    0.224090
# Item 42006    0.224262
# Item 42557    0.228271
# Item 11590    0.229170
# Item 18231    0.244789
# Item 84223    0.258178
# Item 47418    0.264112
# Item 40150    0.281792
# Item 60582    0.322566
# Item 81971    0.333963
# Item 48663    0.335293
# Item 81339    0.345742
# Item 89981    0.345888
# Item 8757     0.382275
# Item 62247    0.415028
# Item 66897    0.443762
# Item 83923    0.463417
# dtype: float64

# %%
cn_comp.plot_item_compar(item = 'Item 83923')

# %% [markdown]
# ## 3. Matemática

# %%
mt_comp = GroupComparator(comp='MT', ano=ano, gps=[0, 1, 2, 3])
df_gp = mt_comp.get_df_gp()
mt_comp.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 533.06;   Std: 115.53
# Branca - Média: 550.01;   Std: 113.60
# Preta - Média: 496.90;   Std: 89.87
# Parda - Média: 503.20;   Std: 95.82
# Geral - Média: 522.27;   Std: 106.03

# %%
mt_comp.plot_hist_scores()

# %%
bin_mt = mt_comp.bin_scores(nota_min=300, nota_max=800)
auc_mt = mt_comp.auc_groups()
sorted_auc_dif_mt = mt_comp.sort_abs_auc_dif()
# Out:
# Item 86907    0.029703
# Item 43906    0.051361
# Item 96485    0.063671
# Item 84945    0.068127
# Item 11720    0.071987
# Item 60724    0.072610
# Item 87751    0.078910
# Item 29915    0.084440
# Item 43940    0.095520
# Item 89162    0.100311
# Item 96366    0.100820
# Item 68172    0.107863
# Item 40005    0.113801
# Item 89339    0.119430
# Item 95803    0.121147
# Item 82352    0.127936
# Item 85691    0.128585
# Item 23866    0.129695
# Item 29086    0.131536
# Item 81452    0.139634
# Item 9189     0.141769
# Item 83860    0.144514
# Item 66556    0.145937
# Item 85776    0.157919
# Item 60235    0.161551
# Item 29402    0.162873
# Item 40235    0.165153
# Item 87141    0.167804
# Item 41047    0.177539
# Item 95556    0.180670
# Item 17384    0.191965
# Item 38563    0.193513
# Item 81410    0.204236
# Item 16539    0.212992
# Item 45300    0.226002
# Item 17360    0.263644
# Item 61485    0.272929
# Item 96088    0.275285
# Item 43322    0.304575
# Item 40717    0.306095
# Item 11758    0.322200
# Item 27493    0.323570
# Item 60584    0.338150
# Item 30042    0.353657
# Item 87821    0.495569
# dtype: float64

# %%
mt_comp.plot_item_compar(item = 'Item 87821')

# %% [markdown]
# ## 4. Linguagens e Códigos

# %%
comp = 'LC'

lc_comp = GroupComparator(comp=comp, ano=ano, gps=[0, 1, 2, 3])
df_gp = lc_comp.get_df_gp()

item_ing = ['Item 48074', 'Item 37043', 'Item 7463', 'Item 54099', 'Item 18212']
item_esp = ['Item 23183', 'Item 33118','Item 88785', 'Item 60767', 'Item 47905']

df_gp_ing = {}
df_gp_esp = {}
df_gp_pt = {}

for g in df_gp.keys():
    df_gp_ing[g] = df_gp[g][df_gp[g]['TP_LINGUA']==0][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_esp[g] = df_gp[g][df_gp[g]['TP_LINGUA']==1][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_pt[g] = df_gp[g][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    
    for col in df_gp[0].columns:
        if col in item_ing:
            df_gp_ing[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==0][col]
        elif col in item_esp:
            df_gp_esp[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==1][col]
        elif col!='NU_INSCRICAO' and col!='NU_NOTA_LC' and col!='TP_LINGUA':
            df_gp_pt[g][col] = df_gp[g][col]

# %% [markdown]
# ### 4.1 Inglês

# %%
print("Proporção de participantes em inglês:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em inglês:
# ND: 0.567
# Branca: 0.623
# Preta: 0.494
# Parda: 0.459
# Geral: 0.532

# %%
lc_comp_ing = GroupComparator(comp=comp, ano=ano, gps=[0, 1, 2, 3])
lc_comp_ing.df_gp = df_gp_ing
lc_comp_ing.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 529.79;   Std: 71.92
# Branca - Média: 538.67;   Std: 64.78
# Preta - Média: 505.73;   Std: 65.06
# Parda - Média: 508.14;   Std: 66.51
# Geral - Média: 522.91;   Std: 67.46

# %%
lc_comp_ing.plot_hist_scores()

# %%
bin_lc_ing = lc_comp_ing.bin_scores(nota_min=350, nota_max=700)
auc_lc_ing = lc_comp_ing.auc_groups()
sorted_auc_dif_lc_ing = lc_comp_ing.sort_abs_auc_dif()
# Out:
# Item 18212    0.232326
# Item 48074    0.353806
# Item 54099    0.369413
# Item 37043    0.432646
# Item 7463     0.658293
# dtype: float64

# %%
lc_comp_ing.plot_item_compar(item = 'Item 7463')

# %% [markdown]
# ### 4.2 Espanhol

# %%
print("Proporção de participantes em espanhol:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em espanhol:
# ND: 0.433
# Branca: 0.377
# Preta: 0.506
# Parda: 0.541
# Geral: 0.468

# %%
lc_comp_esp = GroupComparator(comp=comp, ano=ano, gps=[0, 1, 2, 3])
lc_comp_esp.df_gp = df_gp_esp
lc_comp_esp.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 487.68;   Std: 65.64
# Branca - Média: 500.44;   Std: 60.71
# Preta - Média: 483.12;   Std: 61.50
# Parda - Média: 480.47;   Std: 61.44
# Geral - Média: 487.42;   Std: 61.95

# %%
lc_comp_esp.plot_hist_scores()

# %%
bin_lc_esp = lc_comp_esp.bin_scores(nota_min=350, nota_max=700)
auc_lc_esp = lc_comp_esp.auc_groups()
sorted_auc_dif_lc_esp = lc_comp_esp.sort_abs_auc_dif()
# Out:
# Item 23183    0.145685
# Item 47905    0.152721
# Item 88785    0.154717
# Item 33118    0.234113
# Item 60767    0.290464
# dtype: float64

# %%
lc_comp_esp.plot_item_compar(item = 'Item 60767')

# %% [markdown]
# ### 4.3 Português

# %%
lc_comp_pt = GroupComparator(comp=comp, ano=ano, gps=[0, 1, 2, 3])
lc_comp_pt.df_gp = df_gp_pt
lc_comp_pt.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 511.55;   Std: 72.34
# Branca - Média: 524.27;   Std: 65.93
# Preta - Média: 494.28;   Std: 64.28
# Parda - Média: 493.17;   Std: 65.29
# Geral - Média: 506.29;   Std: 67.31

# %%
lc_comp_pt.plot_hist_scores()

# %%
bin_lc_pt = lc_comp_pt.bin_scores(nota_min=350, nota_max=700)
auc_lc_pt = lc_comp_pt.auc_groups()
sorted_auc_dif_lc_pt = lc_comp_pt.sort_abs_auc_dif()
# Out:
# Item 29586    0.027860
# Item 85925    0.040036
# Item 38057    0.050810
# Item 31174    0.053723
# Item 60715    0.058914
# Item 84380    0.067060
# Item 30469    0.067908
# Item 31891    0.076560
# Item 48314    0.082402
# Item 84452    0.083657
# Item 61636    0.086184
# Item 84042    0.094335
# Item 29528    0.098463
# Item 7069     0.116135
# Item 88888    0.117519
# Item 90150    0.119869
# Item 77759    0.138900
# Item 32474    0.140386
# Item 68416    0.140799
# Item 85411    0.144862
# Item 36865    0.148772
# Item 30995    0.151021
# Item 68284    0.156040
# Item 62046    0.157758
# Item 39530    0.163221
# Item 55024    0.166749
# Item 39670    0.185414
# Item 90020    0.196614
# Item 19655    0.210470
# Item 32266    0.212908
# Item 86768    0.216169
# Item 44273    0.220350
# Item 29181    0.231077
# Item 82891    0.250818
# Item 96950    0.269364
# Item 86322    0.287238
# Item 18642    0.301410
# Item 55771    0.505198
# Item 23784    0.545303
# Item 53474    0.700043
# dtype: float64

# %%
lc_comp_pt.plot_item_compar(item = 'Item 53474')
