# %% [markdown]
# # Compare Sex - ENEM 2009

# %%
import pandas as pd
from CompareGroupsFunctions import *

ano = '2009'

# %% [markdown]
# ## 1. Ciências Humanas

# %%
ch_comp = GroupComparator(comp='CH', ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
df_gp = ch_comp.get_df_gp()
ch_comp.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 512.33;   Std: 104.30
# Feminino - Média: 492.08;   Std: 96.33
# Geral - Média: 500.03;   Std: 100.02

# %%
ch_comp.plot_hist_scores_2groups()

# %%
bin_ch = ch_comp.bin_scores()
auc_ch = ch_comp.auc_groups()
sorted_auc_dif_ch = ch_comp.sort_abs_auc_dif()
# Out:
# Item 60206    0.010238
# Item 60207    0.025294
# Item 58726    0.031445
# Item 60219    0.039181
# Item 58520    0.050197
# Item 60186    0.052955
# Item 60182    0.094999
# Item 60195    0.096766
# Item 60192    0.105969
# Item 60191    0.111000
# Item 60224    0.125355
# Item 60199    0.201893
# Item 60203    0.222947
# Item 60185    0.225222
# Item 60211    0.239001
# Item 60190    0.248759
# Item 60202    0.259985
# Item 60209    0.276811
# Item 60188    0.278125
# Item 60184    0.292862
# Item 60223    0.303668
# Item 60196    0.304265
# Item 60215    0.334015
# Item 60193    0.334016
# Item 58083    0.361545
# Item 60201    0.367051
# Item 60217    0.374103
# Item 60200    0.395469
# Item 60181    0.419166
# Item 58536    0.428383
# Item 60183    0.448675
# Item 60225    0.512019
# Item 60205    0.515307
# Item 60198    0.526017
# Item 58533    0.526230
# Item 58114    0.545907
# Item 60210    0.608300
# Item 60189    0.648111
# Item 60212    0.688193
# Item 60204    0.710040
# Item 60208    0.729347
# Item 60197    0.825053
# Item 60194    0.925170
# Item 58778    0.980633
# Item 60187    0.994330
# dtype: float64

# %%
ch_comp.plot_item_compar(item = 'Item 60187')

# %%
ch_comp.plot_item_compar(item = 'Item 58778')

# %% [markdown]
# ## 2. Ciências da Natureza

# %%
cn_comp = GroupComparator(comp='CN', ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
df_gp = cn_comp.get_df_gp()
cn_comp.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 519.06;   Std: 102.80
# Feminino - Média: 487.74;   Std: 96.20
# Geral - Média: 500.03;   Std: 100.02

# %%
cn_comp.plot_hist_scores_2groups()

# %%
bin_cn = cn_comp.bin_scores()
auc_cn = cn_comp.auc_groups()
sorted_auc_dif_cn = cn_comp.sort_abs_auc_dif()
# Out:
# Item 59311    0.028082
# Item 60152    0.055929
# Item 60151    0.059547
# Item 60147    0.060386
# Item 57978    0.068104
# Item 60138    0.084547
# Item 60088    0.089189
# Item 60148    0.098452
# Item 60144    0.101183
# Item 60146    0.102254
# Item 60086    0.109410
# Item 60136    0.118264
# Item 60142    0.120777
# Item 60145    0.125348
# Item 60092    0.135009
# Item 60143    0.145605
# Item 60137    0.150122
# Item 60139    0.179211
# Item 60141    0.197855
# Item 60091    0.211220
# Item 57968    0.212905
# Item 60140    0.215472
# Item 60132    0.220216
# Item 58396    0.221918
# Item 60127    0.236580
# Item 60133    0.249725
# Item 60134    0.256367
# Item 58443    0.344573
# Item 59286    0.384760
# Item 60150    0.454922
# Item 60087    0.465791
# Item 60126    0.506435
# Item 60149    0.510436
# Item 59275    0.518872
# Item 60135    0.562423
# Item 60128    0.622520
# Item 60129    0.632420
# Item 60130    0.673177
# Item 60090    0.693477
# Item 60083    0.725663
# Item 60089    0.745122
# Item 60131    0.749092
# Item 59321    1.183083
# Item 60085    1.237677
# Item 60084    1.518343
# dtype: float64

# %%
cn_comp.plot_item_compar(item = 'Item 60084')

# %%
cn_comp.plot_item_compar(item = 'Item 60085')

# %%
cn_comp.plot_item_compar(item = 'Item 59321')

# %% [markdown]
# ## 3. Matemática

# %%
mt_comp = GroupComparator(comp='MT', ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
df_gp = mt_comp.get_df_gp()
mt_comp.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 520.54;   Std: 110.01
# Feminino - Média: 486.87;   Std: 90.66
# Geral - Média: 500.03;   Std: 100.03

# %%
mt_comp.plot_hist_scores_2groups()

# %%
bin_mt = mt_comp.bin_scores(nota_min=300, nota_max=800)
auc_mt = mt_comp.auc_groups()
sorted_auc_dif_mt = mt_comp.sort_abs_auc_dif()
# Out:
# Item 60252    0.013725
# Item 60260    0.017351
# Item 60227    0.027997
# Item 58784    0.034068
# Item 60257    0.038498
# Item 60261    0.074453
# Item 60263    0.115632
# Item 60259    0.143335
# Item 60262    0.156240
# Item 60258    0.169867
# Item 58672    0.187150
# Item 60229    0.188218
# Item 58675    0.207101
# Item 60238    0.211484
# Item 60241    0.222841
# Item 60250    0.230912
# Item 60244    0.235302
# Item 60249    0.261111
# Item 60239    0.281186
# Item 58815    0.326601
# Item 59010    0.328873
# Item 60242    0.341116
# Item 60232    0.342389
# Item 60236    0.344701
# Item 60237    0.361303
# Item 60235    0.367290
# Item 60251    0.374684
# Item 60255    0.406442
# Item 60228    0.407958
# Item 60234    0.414092
# Item 60253    0.425331
# Item 60231    0.464739
# Item 58608    0.465454
# Item 60230    0.466799
# Item 60248    0.472740
# Item 60256    0.490731
# Item 60240    0.547708
# Item 60254    0.573810
# Item 60233    0.599526
# Item 60245    0.602535
# Item 59484    0.637262
# Item 60246    0.645557
# Item 60243    0.692625
# Item 60226    0.756668
# Item 60247    1.018324
# dtype: float64

# %%
mt_comp.plot_item_compar(item = 'Item 60247')

# %% [markdown]
# ## 4. Linguagens e Códigos

# %%
lc_comp = GroupComparator(comp='LC', ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
df_gp = lc_comp.get_df_gp()
lc_comp.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 497.71;   Std: 103.27
# Feminino - Média: 501.52;   Std: 97.84
# Geral - Média: 500.03;   Std: 100.02

# %%
lc_comp.plot_hist_scores_2groups()

# %%
bin_lc = lc_comp.bin_scores(nota_min=300, nota_max=800)
auc_lc = lc_comp.auc_groups()
sorted_auc_dif_lc = lc_comp.sort_abs_auc_dif()
# Out:
# Item 60177    0.040451
# Item 60218    0.070453
# Item 60157    0.078027
# Item 60154    0.082478
# Item 60180    0.090908
# Item 60123    0.092630
# Item 60125    0.118046
# Item 60156    0.118463
# Item 59578    0.127277
# Item 60153    0.145770
# Item 60178    0.157768
# Item 60167    0.158743
# Item 60173    0.210937
# Item 58219    0.216211
# Item 59558    0.224520
# Item 59561    0.230123
# Item 60168    0.246712
# Item 60172    0.253842
# Item 59610    0.258129
# Item 60163    0.268879
# Item 60161    0.279754
# Item 60158    0.307144
# Item 59175    0.317129
# Item 59074    0.323419
# Item 60176    0.326751
# Item 60174    0.390790
# Item 60162    0.397507
# Item 60179    0.412412
# Item 60213    0.441910
# Item 60166    0.447219
# Item 60221    0.498308
# Item 60169    0.527824
# Item 60171    0.529843
# Item 60220    0.559376
# Item 60214    0.565768
# Item 60222    0.567713
# Item 60216    0.567964
# Item 60165    0.587355
# Item 60160    0.592680
# Item 60164    0.601726
# Item 60155    0.769290
# Item 60170    0.773197
# Item 60124    0.922873
# Item 60175    0.968898
# dtype: float64

# %%
lc_comp.plot_item_compar(item = 'Item 60175')

# %%
lc_comp.plot_item_compar(item = 'Item 60124')
