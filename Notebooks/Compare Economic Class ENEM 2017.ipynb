# %% [markdown]
# # Compare Economic Class ENEM 2017

# %%
import pandas as pd
from CompareGroupsFunctions import *

ano = '2017'
gp_feat = 'CLASSE'
gp_name = 'classe'
gp_map = {'E': 'Classe E',
          'D': 'Classe D',
          'C': 'Classe C',
          'B': 'Classe B',
          'A': 'Classe A'}

# %% [markdown]
# ## 1. Ciências Humanas

# %%
ch_comp = GroupComparator(comp='CH', ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
df_gp = ch_comp.get_df_gp()
ch_comp.print_mean_std()
# Out:
# Média e Std por classe:
# Classe E - Média: 494.06;   Std: 75.19
# Classe D - Média: 531.85;   Std: 77.64
# Classe C - Média: 568.90;   Std: 79.02
# Classe B - Média: 609.66;   Std: 71.61
# Classe A - Média: 624.14;   Std: 70.16
# Geral - Média: 516.72;   Std: 82.96

# %%
ch_comp.plot_hist_scores()

# %%
bin_ch = ch_comp.bin_scores(nota_min=400, nota_max=800, step=20)
auc_ch = ch_comp.auc_groups()
sorted_auc_dif_ch = ch_comp.sort_abs_auc_dif()
# Out:
# Item 38250    0.009520
# Item 25281    0.010103
# Item 67012    0.010489
# Item 49683    0.012754
# Item 29085    0.014869
# Item 83848    0.017030
# Item 76970    0.018197
# Item 20109    0.018549
# Item 79027    0.019469
# Item 84226    0.022914
# Item 27214    0.024031
# Item 75940    0.026869
# Item 8456     0.027257
# Item 24918    0.030930
# Item 83836    0.033279
# Item 82449    0.033363
# Item 24935    0.034118
# Item 43284    0.034839
# Item 84165    0.037214
# Item 31360    0.037598
# Item 81598    0.043279
# Item 47840    0.045005
# Item 18647    0.045193
# Item 81916    0.045855
# Item 25316    0.046179
# Item 96575    0.046527
# Item 82451    0.047320
# Item 67329    0.048675
# Item 8172     0.050372
# Item 37521    0.054641
# Item 43294    0.060278
# Item 79005    0.063663
# Item 44604    0.064165
# Item 6990     0.064476
# Item 82228    0.066396
# Item 23043    0.068601
# Item 45306    0.069581
# Item 78146    0.074246
# Item 66214    0.082825
# Item 84192    0.083311
# Item 30150    0.103649
# Item 7962     0.104774
# Item 49661    0.106495
# Item 47012    0.111769
# Item 84128    0.140850
# dtype: float64

# %%
ch_comp.plot_item_compar(item = 'Item 84128')

# %% [markdown]
# ## 2. Ciências da Natureza

# %%
cn_comp = GroupComparator(comp='CN', ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
df_gp = cn_comp.get_df_gp()
cn_comp.print_mean_std()
# Out:
# Média e Std por classe:
# Classe E - Média: 488.20;   Std: 61.76
# Classe D - Média: 518.70;   Std: 69.34
# Classe C - Média: 556.01;   Std: 74.49
# Classe B - Média: 595.79;   Std: 72.86
# Classe A - Média: 609.12;   Std: 74.38
# Geral - Média: 508.43;   Std: 72.35

# %%
cn_comp.plot_hist_scores()

# %%
bin_cn = cn_comp.bin_scores(nota_min=400, nota_max=760, step=20)
auc_cn = cn_comp.auc_groups()
sorted_auc_dif_cn = cn_comp.sort_abs_auc_dif()
# Out:
# Item 60699    0.010474
# Item 18231    0.010876
# Item 81968    0.021108
# Item 61269    0.021312
# Item 59980    0.021447
# Item 40150    0.022977
# Item 48655    0.024024
# Item 81944    0.028038
# Item 60582    0.029847
# Item 47418    0.030097
# Item 84223    0.030551
# Item 89981    0.031375
# Item 81971    0.035645
# Item 84291    0.036128
# Item 23921    0.036277
# Item 49555    0.040357
# Item 30022    0.041997
# Item 43703    0.042522
# Item 43722    0.043873
# Item 48663    0.043892
# Item 68394    0.045527
# Item 62247    0.046300
# Item 83923    0.046700
# Item 42557    0.046981
# Item 76032    0.050504
# Item 42006    0.052775
# Item 88873    0.056955
# Item 29460    0.058683
# Item 82421    0.060800
# Item 17983    0.070889
# Item 81339    0.071434
# Item 18349    0.072487
# Item 87974    0.072934
# Item 8757     0.076309
# Item 43880    0.077176
# Item 56286    0.082385
# Item 88958    0.083175
# Item 66897    0.086490
# Item 78598    0.097191
# Item 26843    0.100194
# Item 64059    0.133019
# Item 11793    0.156035
# Item 11590    0.157605
# Item 81780    0.178466
# Item 59829    0.190510
# dtype: float64

# %%
cn_comp.plot_item_compar(item = 'Item 59829')

# %%
cn_comp.plot_item_compar(item = 'Item 81780')

# %% [markdown]
# ## 3. Matemática

# %%
mt_comp = GroupComparator(comp='MT', ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
df_gp = mt_comp.get_df_gp()
mt_comp.print_mean_std()
# Out:
# Média e Std por classe:
# Classe E - Média: 491.06;   Std: 85.85
# Classe D - Média: 539.17;   Std: 101.09
# Classe C - Média: 593.14;   Std: 115.45
# Classe B - Média: 657.69;   Std: 119.54
# Classe A - Média: 688.77;   Std: 120.93
# Geral - Média: 522.27;   Std: 106.03

# %%
mt_comp.plot_hist_scores()

# %%
bin_mt = mt_comp.bin_scores(nota_min=400, nota_max=900, step=20)
auc_mt = mt_comp.auc_groups()
sorted_auc_dif_mt = mt_comp.sort_abs_auc_dif()
# Out:
# Item 38563    0.005756
# Item 43940    0.007970
# Item 11720    0.009948
# Item 16539    0.013612
# Item 68172    0.013908
# Item 43322    0.014258
# Item 95556    0.014895
# Item 87751    0.015592
# Item 41047    0.016302
# Item 81410    0.018339
# Item 60584    0.018534
# Item 43906    0.019298
# Item 17384    0.023100
# Item 89162    0.023268
# Item 95803    0.023406
# Item 45300    0.023897
# Item 29086    0.024591
# Item 86907    0.025462
# Item 40235    0.026189
# Item 40005    0.028297
# Item 85776    0.028511
# Item 9189     0.029589
# Item 81452    0.030507
# Item 87821    0.030725
# Item 30042    0.034221
# Item 89339    0.035987
# Item 61485    0.037976
# Item 27493    0.041030
# Item 85691    0.044002
# Item 87141    0.044585
# Item 17360    0.047437
# Item 29915    0.060285
# Item 82352    0.067184
# Item 29402    0.070044
# Item 83860    0.071736
# Item 66556    0.072128
# Item 60235    0.073174
# Item 96088    0.079266
# Item 96485    0.081466
# Item 96366    0.099382
# Item 84945    0.112586
# Item 40717    0.115549
# Item 60724    0.120853
# Item 23866    0.120857
# Item 11758    0.178022
# dtype: float64

# %%
mt_comp.plot_item_compar(item = 'Item 11758')

# %%
mt_comp.plot_item_compar(item = 'Item 23866')

# %%
mt_comp.plot_item_compar(item = 'Item 60724')

# %% [markdown]
# ## 4. Linguagens e Códigos

# %%
comp = 'LC'

lc_comp = GroupComparator(comp=comp, ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
df_gp = lc_comp.get_df_gp()

item_ing = ['Item 48074', 'Item 37043', 'Item 7463', 'Item 54099', 'Item 18212']
item_esp = ['Item 23183', 'Item 33118','Item 88785', 'Item 60767', 'Item 47905']

df_gp_ing = {}
df_gp_esp = {}
df_gp_pt = {}

for g in df_gp.keys():
    df_gp_ing[g] = df_gp[g][df_gp[g]['TP_LINGUA']==0][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_esp[g] = df_gp[g][df_gp[g]['TP_LINGUA']==1][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_pt[g] = df_gp[g][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    
    for col in df_gp[list(df_gp.keys())[0]].columns:
        if col in item_ing:
            df_gp_ing[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==0][col]
        elif col in item_esp:
            df_gp_esp[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==1][col]
        elif col!='NU_INSCRICAO' and col!='NU_NOTA_LC' and col!='TP_LINGUA':
            df_gp_pt[g][col] = df_gp[g][col]

# %% [markdown]
# ### 4.1 Inglês

# %%
print("Proporção de participantes em inglês:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em inglês:
# Classe E: 0.441
# Classe D: 0.610
# Classe C: 0.726
# Classe B: 0.859
# Classe A: 0.905
# Geral: 0.532

# %%
lc_comp_ing = GroupComparator(comp=comp, ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
lc_comp_ing.df_gp = df_gp_ing
lc_comp_ing.print_mean_std()
# Out:
# Média e Std por classe:
# Classe E - Média: 498.73;   Std: 63.73
# Classe D - Média: 530.14;   Std: 60.37
# Classe C - Média: 558.39;   Std: 58.02
# Classe B - Média: 585.23;   Std: 51.96
# Classe A - Média: 593.89;   Std: 51.36
# Geral - Média: 522.91;   Std: 67.46

# %%
lc_comp_ing.plot_hist_scores()

# %%
bin_lc_ing = lc_comp_ing.bin_scores(nota_min=350, nota_max=750)
auc_lc_ing = lc_comp_ing.auc_groups()
sorted_auc_dif_lc_ing = lc_comp_ing.sort_abs_auc_dif()
# Out:
# Item 37043    0.116017
# Item 18212    0.118427
# Item 54099    0.168494
# Item 48074    0.229331
# Item 7463     0.290298
# dtype: float64

# %%
lc_comp_ing.plot_item_compar(item = 'Item 7463')

# %%
lc_comp_ing.plot_item_compar(item = 'Item 48074')

# %%
lc_comp_ing.plot_item_compar(item = 'Item 54099')

# %%
lc_comp_ing.plot_item_compar(item = 'Item 37043')

# %% [markdown]
# ### 4.2 Espanhol

# %%
print("Proporção de participantes em espanhol:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em espanhol:
# Classe E: 0.559
# Classe D: 0.390
# Classe C: 0.274
# Classe B: 0.141
# Classe A: 0.095
# Geral: 0.468

# %%
lc_comp_esp = GroupComparator(comp=comp, ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
lc_comp_esp.df_gp = df_gp_esp
lc_comp_esp.print_mean_std()
# Out:
# Média e Std por classe:
# Classe E - Média: 478.38;   Std: 60.30
# Classe D - Média: 506.06;   Std: 58.56
# Classe C - Média: 522.94;   Std: 58.80
# Classe B - Média: 540.74;   Std: 57.96
# Classe A - Média: 541.31;   Std: 64.30
# Geral - Média: 487.42;   Std: 61.95

# %%
lc_comp_esp.plot_hist_scores()

# %%
bin_lc_esp = lc_comp_esp.bin_scores(nota_min=350, nota_max=650)
auc_lc_esp = lc_comp_esp.auc_groups()
sorted_auc_dif_lc_esp = lc_comp_esp.sort_abs_auc_dif()
# Out:
# Item 47905    0.043951
# Item 88785    0.055017
# Item 60767    0.066231
# Item 23183    0.159120
# Item 33118    0.220059
# dtype: float64

# %%
lc_comp_esp.plot_item_compar(item = 'Item 33118')

# %% [markdown]
# ### 4.3 Português

# %%
lc_comp_pt = GroupComparator(comp=comp, ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
lc_comp_pt.df_gp = df_gp_pt
lc_comp_pt.print_mean_std()
# Out:
# Média e Std por classe:
# Classe E - Média: 487.36;   Std: 62.66
# Classe D - Média: 520.76;   Std: 60.81
# Classe C - Média: 548.68;   Std: 60.35
# Classe B - Média: 578.98;   Std: 55.06
# Classe A - Média: 588.88;   Std: 54.94
# Geral - Média: 506.29;   Std: 67.31

# %%
lc_comp_pt.plot_hist_scores()

# %%
bin_lc_pt = lc_comp_pt.bin_scores(nota_min=350, nota_max=750)
auc_lc_pt = lc_comp_pt.auc_groups()
sorted_auc_dif_lc_pt = lc_comp_pt.sort_abs_auc_dif()
# Out:
# Item 88888    0.013657
# Item 18642    0.016861
# Item 31891    0.017211
# Item 61636    0.017456
# Item 60715    0.020659
# Item 38057    0.021050
# Item 32474    0.021120
# Item 7069     0.023235
# Item 68416    0.024011
# Item 84042    0.026894
# Item 30469    0.028396
# Item 85925    0.029477
# Item 82891    0.032158
# Item 62046    0.032584
# Item 29528    0.032679
# Item 39670    0.033954
# Item 86322    0.035748
# Item 29181    0.036258
# Item 55771    0.038219
# Item 68284    0.039378
# Item 30995    0.040175
# Item 48314    0.040195
# Item 32266    0.043475
# Item 85411    0.043516
# Item 77759    0.047395
# Item 90020    0.051794
# Item 55024    0.056883
# Item 23784    0.057715
# Item 44273    0.058827
# Item 53474    0.060049
# Item 31174    0.065023
# Item 84452    0.068001
# Item 36865    0.068695
# Item 29586    0.069458
# Item 39530    0.079353
# Item 19655    0.094991
# Item 86768    0.095196
# Item 96950    0.104028
# Item 90150    0.111896
# Item 84380    0.131375
# dtype: float64

# %%
lc_comp_pt.plot_item_compar(item = 'Item 84380')

# %%
lc_comp_pt.plot_item_compar(item = 'Item 90150')
