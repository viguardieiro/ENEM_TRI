# %% [markdown]
# # Compare Economic Class ENEM 2019

# %%
import pandas as pd
from CompareGroupsFunctions import *
import matplotlib.pyplot as plt
import seaborn as sns

ano = '2019'
gp_feat = 'CLASSE'
gp_name = 'classe'
gp_map = {'alta': '2+ MW',
          'média': '1/2-2 MW',
          'baixa': '0-1/2 MW'
          }

df_grupo = pd.read_csv("../Data/Processed/ENEM"+str(ano)+"/All_grupos.csv")
nu_grupo = df_grupo['NU_INSCRICAO'].tolist()

# %% [markdown]
# ## 1. Ciências Humanas

# %%
ch_comp = GroupComparator(comp='CH', ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
df_gp = ch_comp.get_df_gp()
ch_comp.print_mean_std()
# Out:
# Média e Std por classe:
# 2+ MW - Média: 584.49;   Std: 73.12
# 1/2-2 MW - Média: 529.15;   Std: 76.51
# 0-1/2 MW - Média: 481.45;   Std: 73.32
# Geral - Média: 506.10;   Std: 81.10

# %%
#ch_comp.plot_hist_scores()
for g in df_gp.keys():
    if g=='Geral':
        fig = sns.kdeplot(df_gp[g]["NU_NOTA_CH"], label=g, linestyle="--", color='k')
    else:
        fig = sns.kdeplot(df_gp[g]["NU_NOTA_CH"], label=ch_comp.gp_map[g])

plt.xlabel('Score')
plt.title('Score density by economical class')
plt.legend(loc='upper left')
plt.show()
plt.savefig('ScoreDensity-CH2019.png')

# %%
bin_ch = ch_comp.bin_scores(nota_min=300, nota_max=800, step=20)
auc_ch = ch_comp.auc_groups()
sorted_auc_dif_ch = ch_comp.sort_abs_auc_dif()
# Out:
# Item 111877    0.002623
# Item 83820     0.003223
# Item 76955     0.006072
# Item 84769     0.006149
# Item 33960     0.008224
# Item 118108    0.008996
# Item 78903     0.009206
# Item 84888     0.009656
# Item 85139     0.011632
# Item 87709     0.013804
# Item 66498     0.014752
# Item 97975     0.017241
# Item 88306     0.018016
# Item 95648     0.018804
# Item 118029    0.019513
# Item 118158    0.021647
# Item 88194     0.021830
# Item 96302     0.021943
# Item 87057     0.024076
# Item 96596     0.024665
# Item 77940     0.024849
# Item 112135    0.026578
# Item 118034    0.028722
# Item 84147     0.030965
# Item 111844    0.032271
# Item 88308     0.032983
# Item 118125    0.034188
# Item 96447     0.035219
# Item 89147     0.035346
# Item 84811     0.035589
# Item 88233     0.039325
# Item 118033    0.039608
# Item 118022    0.042519
# Item 86751     0.044206
# Item 118054    0.049919
# Item 81689     0.055619
# Item 118038    0.055881
# Item 111820    0.057329
# Item 97013     0.058070
# Item 11601     0.060359
# Item 111894    0.062641
# Item 118067    0.063083
# Item 118024    0.067193
# Item 66219     0.073483
# Item 86934     0.086924
# dtype: float64

# %%
ch_comp.plot_item_compar(item = 'Item 86934')

# %%
ch_comp.plot_item_compar(item = 'Item 66219')

# %% [markdown]
# ## 2. Ciências da Natureza

# %%
cn_comp = GroupComparator(comp='CN', ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
df_gp = cn_comp.get_df_gp()
cn_comp.print_mean_std()
# Out:
# Média e Std por classe:
# 2+ MW - Média: 556.26;   Std: 74.41
# 1/2-2 MW - Média: 497.74;   Std: 74.17
# 0-1/2 MW - Média: 452.07;   Std: 64.07
# Geral - Média: 476.48;   Std: 75.76

# %%
#cn_comp.plot_hist_scores()
for g in df_gp.keys():
    if g=='Geral':
        fig = sns.kdeplot(df_gp[g]["NU_NOTA_CN"], label=g, linestyle="--", color='k')
    else:
        fig = sns.kdeplot(df_gp[g]["NU_NOTA_CN"], label=cn_comp.gp_map[g])

plt.xlabel('Score')
plt.title('Score density by economical class')
plt.legend(loc='upper left')
plt.show()
plt.savefig('ScoreDensity-CN2019.png')

# %%
bin_cn = cn_comp.bin_scores(nota_min=300, nota_max=760, step=20)
auc_cn = cn_comp.auc_groups()
sorted_auc_dif_cn = cn_comp.sort_abs_auc_dif()
# Out:
# Item 84568     0.002977
# Item 111601    0.006610
# Item 29776     0.010525
# Item 96556     0.012485
# Item 7529      0.014030
# Item 19223     0.014657
# Item 86521     0.016360
# Item 89515     0.016993
# Item 31718     0.022813
# Item 39290     0.027269
# Item 89298     0.027636
# Item 117988    0.028143
# Item 60311     0.028997
# Item 111545    0.030526
# Item 85548     0.030945
# Item 83609     0.031606
# Item 81478     0.032290
# Item 24104     0.033048
# Item 89150     0.033106
# Item 78504     0.033429
# Item 117746    0.035964
# Item 111705    0.036547
# Item 117883    0.036745
# Item 117642    0.036834
# Item 88853     0.037633
# Item 83441     0.038760
# Item 14273     0.039126
# Item 82364     0.039464
# Item 19407     0.042823
# Item 111624    0.044097
# Item 55328     0.046286
# Item 82236     0.046570
# Item 7629      0.048657
# Item 117979    0.052029
# Item 49600     0.052160
# Item 89772     0.052808
# Item 117999    0.055412
# Item 83526     0.056595
# Item 117875    0.059115
# Item 97169     0.062504
# Item 82490     0.064291
# Item 117890    0.066544
# Item 54381     0.088628
# Item 117868    0.094712
# Item 117836    0.097391
# dtype: float64

# %%
cn_comp.plot_item_compar(item = 'Item 117868')

# %%
cn_comp.plot_item_compar(item = 'Item 117875')

# %% [markdown]
# ## 3. Matemática

# %%
mt_comp = GroupComparator(comp='MT', ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
df_gp = mt_comp.get_df_gp()
mt_comp.print_mean_std()
# Out:
# Média e Std por classe:
# 2+ MW - Média: 650.46;   Std: 116.29
# 1/2-2 MW - Média: 558.06;   Std: 108.37
# 0-1/2 MW - Média: 491.40;   Std: 86.89
# Geral - Média: 527.62;   Std: 108.81

# %%
#mt_comp.plot_hist_scores()

for g in df_gp.keys():
    if g=='Geral':
        fig = sns.kdeplot(df_gp[g]["NU_NOTA_MT"], label=g, linestyle="--", color='k')
    else:
        fig = sns.kdeplot(df_gp[g]["NU_NOTA_MT"], label=mt_comp.gp_map[g])

plt.xlabel('Score')
plt.title('Score density by economical class')
plt.legend(loc='upper left')
plt.show()
plt.savefig('ScoreDensity-MT2019.png')

# %%
bin_mt = mt_comp.bin_scores(nota_min=360, nota_max=800, step=20)
auc_mt = mt_comp.auc_groups()
sorted_auc_dif_mt = mt_comp.sort_abs_auc_dif()
# Out:
# Item 111593    0.005964
# Item 117743    0.007931
# Item 63187     0.009129
# Item 30740     0.012973
# Item 17642     0.013518
# Item 117783    0.014216
# Item 117818    0.014587
# Item 117607    0.015993
# Item 117798    0.018980
# Item 83955     0.020473
# Item 13303     0.020779
# Item 111696    0.021412
# Item 54448     0.022418
# Item 117635    0.023324
# Item 31184     0.027191
# Item 30570     0.031636
# Item 117845    0.032917
# Item 84374     0.033467
# Item 8401      0.036464
# Item 86432     0.036469
# Item 28434     0.036483
# Item 117725    0.036643
# Item 111518    0.036877
# Item 14324     0.040297
# Item 89634     0.040353
# Item 83792     0.041992
# Item 23065     0.042483
# Item 117767    0.043154
# Item 111608    0.043247
# Item 42803     0.046639
# Item 30436     0.046837
# Item 117950    0.047278
# Item 117612    0.049597
# Item 39708     0.050474
# Item 9779      0.052193
# Item 8442      0.053195
# Item 8368      0.055212
# Item 10360     0.058409
# Item 83754     0.069960
# Item 84409     0.079344
# Item 83994     0.084829
# Item 63808     0.084984
# Item 117726    0.102867
# Item 18002     0.116155
# Item 78445     0.118932
# dtype: float64

# %%
mt_comp.plot_item_compar(item = 'Item 78445')

# %%
mt_comp.plot_item_compar(item = 'Item 18002')

# %%
mt_comp.plot_item_compar(item = 'Item 117726')

# %% [markdown]
# ## 4. Linguagens e Códigos

# %%
comp = 'LC'

lc_comp = GroupComparator(comp=comp, ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
df_gp = lc_comp.get_df_gp()

item_ing = ['Item 55166', 'Item 54110', 'Item 23564', 'Item 31954', 'Item 118180']
item_esp = ['Item 96705', 'Item 118222','Item 39016', 'Item 118167', 'Item 48558']

df_gp_ing = {}
df_gp_esp = {}
df_gp_pt = {}

for g in df_gp.keys():
    df_gp_ing[g] = df_gp[g][df_gp[g]['TP_LINGUA']==0][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_esp[g] = df_gp[g][df_gp[g]['TP_LINGUA']==1][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_pt[g] = df_gp[g][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    
    for col in df_gp[list(df_gp.keys())[0]].columns:
        if col in item_ing:
            df_gp_ing[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==0][col]
        elif col in item_esp:
            df_gp_esp[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==1][col]
        elif col!='NU_INSCRICAO' and col!='NU_NOTA_LC' and col!='TP_LINGUA':
            df_gp_pt[g][col] = df_gp[g][col]

# %%
print("Total de participantes em inglês:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {df_gp_pt[g].shape[0]}")
    else:
        print(f"{lc_comp.gp_map[g]}: {df_gp_pt[g].shape[0]}")
# Out:
# Total de participantes em inglês:
# 2+ MW: 99632
# 1/2-2 MW: 404411
# 0-1/2 MW: 694977
# Geral: 1199020

# %%
for g in df_gp.keys():
    if g=='Geral':
        fig = sns.kdeplot(df_gp_pt[g]["NU_NOTA_LC"], label=g, linestyle="--", color='k')
    else:
        fig = sns.kdeplot(df_gp_pt[g]["NU_NOTA_LC"], label=lc_comp.gp_map[g])

plt.xlabel('Score')
plt.title('Score density by economical class')
plt.legend(loc='upper left')
plt.show()
plt.savefig('ScoreDensity-LC2019.png')

# %% [markdown]
# ### 4.1 Inglês

# %%
print("Total de participantes em inglês:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {df_gp_ing[g].shape[0]}")
    else:
        print(f"{lc_comp.gp_map[g]}: {df_gp_ing[g].shape[0]}")
# Out:
# Total de participantes em inglês:
# 2+ MW: 83409
# 1/2-2 MW: 259454
# 0-1/2 MW: 305442
# Geral: 648305

# %%
print("Proporção de participantes em inglês:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em inglês:
# 2+ MW: 0.837
# 1/2-2 MW: 0.642
# 0-1/2 MW: 0.439
# Geral: 0.541

# %%
lc_comp_ing = GroupComparator(comp=comp, ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
lc_comp_ing.df_gp = df_gp_ing
lc_comp_ing.print_mean_std()
# Out:
# Média e Std por classe:
# 2+ MW - Média: 584.33;   Std: 47.53
# 1/2-2 MW - Média: 549.46;   Std: 54.91
# 0-1/2 MW - Média: 510.72;   Std: 61.30
# Geral - Média: 535.69;   Std: 62.79

# %%
lc_comp_ing.plot_hist_scores()

# %%
bin_lc_ing = lc_comp_ing.bin_scores(nota_min=350, nota_max=750, step=20)
auc_lc_ing = lc_comp_ing.auc_groups()
sorted_auc_dif_lc_ing = lc_comp_ing.sort_abs_auc_dif()
# Out:
# Item 55166     0.039215
# Item 31954     0.048640
# Item 54110     0.086810
# Item 23564     0.119148
# Item 118180    0.175313
# dtype: float64

# %%
lc_comp_ing.plot_item_compar(item = 'Item 118180')

# %%
lc_comp_ing.plot_item_compar(item = 'Item 23564')

# %%
lc_comp_ing.plot_item_compar(item = 'Item 54110')

# %%
lc_comp_ing.plot_item_compar(item = 'Item 55166')

# %%
lc_comp_ing.plot_item_compar(item = 'Item 31954')

# %%
for g in df_gp.keys():
    if g=='Geral':
        fig = sns.kdeplot(df_gp_ing[g]["NU_NOTA_LC"], label='All', linestyle="--", color='k')
    else:
        fig = sns.kdeplot(df_gp_ing[g]["NU_NOTA_LC"], label=lc_comp.gp_map[g])

plt.xlim(200, 800)
plt.xlabel('Score')
plt.title('Score density by economical class - English')
plt.legend(loc='upper left')
#plt.show()
plt.savefig('ScoreDensity-LC2019-English.png')

# %% [markdown]
# ### 4.2 Espanhol

# %%
print("Total de participantes em espanhol:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {df_gp[g][df_gp[g]['TP_LINGUA']==1].shape[0]}")
    else:
        print(f"{lc_comp.gp_map[g]}: {df_gp[g][df_gp[g]['TP_LINGUA']==1].shape[0]}")
# Out:
# Total de participantes em espanhol:
# 2+ MW: 16223
# 1/2-2 MW: 144957
# 0-1/2 MW: 389535
# Geral: 550715

# %%
print("Proporção de participantes em espanhol:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em espanhol:
# 2+ MW: 0.163
# 1/2-2 MW: 0.358
# 0-1/2 MW: 0.561
# Geral: 0.459

# %%
lc_comp_esp = GroupComparator(comp=comp, ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
lc_comp_esp.df_gp = df_gp_esp
lc_comp_esp.print_mean_std()
# Out:
# Média e Std por classe:
# 2+ MW - Média: 543.10;   Std: 55.17
# 1/2-2 MW - Média: 521.43;   Std: 56.09
# 0-1/2 MW - Média: 490.43;   Std: 59.61
# Geral - Média: 500.14;   Std: 60.59

# %%
lc_comp_esp.plot_hist_scores()

# %%
bin_lc_esp = lc_comp_esp.bin_scores(nota_min=350, nota_max=750)
auc_lc_esp = lc_comp_esp.auc_groups()
sorted_auc_dif_lc_esp = lc_comp_esp.sort_abs_auc_dif()
# Out:
# Item 118167    0.010651
# Item 118222    0.023501
# Item 48558     0.024004
# Item 39016     0.034591
# Item 96705     0.047613
# dtype: float64

# %%
lc_comp_esp.plot_item_compar(item = 'Item 96705')

# %%
for g in df_gp.keys():
    if g=='Geral':
        fig = sns.kdeplot(df_gp_esp[g]["NU_NOTA_LC"], label='All', linestyle="--", color='k')
    else:
        fig = sns.kdeplot(df_gp_esp[g]["NU_NOTA_LC"], label=lc_comp.gp_map[g])

plt.xlim(200, 800)
plt.xlabel('Score')
plt.title('Score density by economical class - Spanish')
plt.legend(loc='upper left')
#plt.show()
plt.savefig('ScoreDensity-LC2019-Spanish.png')

# %% [markdown]
# ### 4.3 Português

# %%
lc_comp_pt = GroupComparator(comp=comp, ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
lc_comp_pt.df_gp = df_gp_pt
lc_comp_pt.print_mean_std()
# Out:
# Média e Std por classe:
# 2+ MW - Média: 577.62;   Std: 51.17
# 1/2-2 MW - Média: 539.41;   Std: 56.95
# 0-1/2 MW - Média: 499.35;   Std: 61.19
# Geral - Média: 519.36;   Std: 64.28

# %%
lc_comp_pt.plot_hist_scores()

# %%
bin_lc_pt = lc_comp_pt.bin_scores(nota_min=350, nota_max=750)
auc_lc_pt = lc_comp_pt.auc_groups()
sorted_auc_dif_lc_pt = lc_comp_pt.sort_abs_auc_dif()
# Out:
# Item 86496     0.004812
# Item 96525     0.005186
# Item 59976     0.007097
# Item 23833     0.009344
# Item 118147    0.013759
# Item 32261     0.014332
# Item 89874     0.015331
# Item 118134    0.016219
# Item 118235    0.016982
# Item 77356     0.017176
# Item 118118    0.017413
# Item 118165    0.017642
# Item 118161    0.018429
# Item 86932     0.018662
# Item 118117    0.018989
# Item 24785     0.019795
# Item 118276    0.020823
# Item 118207    0.023145
# Item 118306    0.027359
# Item 14169     0.027603
# Item 89550     0.028943
# Item 118264    0.031336
# Item 118174    0.039604
# Item 118299    0.040862
# Item 76167     0.042040
# Item 118278    0.043416
# Item 118028    0.044421
# Item 90165     0.044705
# Item 118103    0.047211
# Item 89317     0.050624
# Item 68624     0.051840
# Item 86563     0.052991
# Item 118215    0.055850
# Item 118170    0.063485
# Item 118260    0.073435
# Item 118256    0.076610
# Item 81992     0.078699
# Item 118246    0.100990
# Item 118232    0.108894
# Item 118192    0.147905
# dtype: float64

# %%
lc_comp_pt.plot_item_compar(item = 'Item 118232')

# %%
lc_comp_pt.plot_item_compar(item = 'Item 118192')

# %%
df_gp['alta']
# Out:
#          NU_INSCRICAO  NU_NOTA_LC  TP_LINGUA  Item 55166  Item 54110  \
# 67       190001599147       549.9          0           1           1
# 71       190001520694       573.4          0           1           1
# 118      190001602631       602.3          1           0           0
# 130      190001602646       569.6          0           1           1
# 198      190001244962       544.2          0           1           1
# ...               ...         ...        ...         ...         ...
# 1198927  190005424397       509.5          1           0           0
# 1198954  190006059681       582.0          1           0           0
# 1198957  190005876718       495.8          1           0           0
# 1198982  190005943805       649.0          0           1           1
# 1198989  190006065537       567.5          0           1           1
#
#          Item 23564  Item 31954  Item 118180  Item 96705  Item 118222  ...  \
# 67                1           0            0           0            0  ...
# 71                1           1            0           0            0  ...
# 118               0           0            0           0            1  ...
# 130               1           1            1           0            0  ...
# 198               0           1            0           0            0  ...
# ...             ...         ...          ...         ...          ...  ...
# 1198927           0           0            0           0            0  ...
# 1198954           0           0            0           0            1  ...
# 1198957           0           0            0           0            1  ...
# 1198982           1           1            1           0            0  ...
# 1198989           1           1            1           0            0  ...
#
#          Item 86932  Item 24785  Item 118028  Item 118246  Item 77356  \
# 67                1           1            0            1           0
# 71                0           1            1            0           1
# 118               1           1            0            0           1
# 130               1           1            1            1           1
# 198               0           1            0            1           0
# ...             ...         ...          ...          ...         ...
# 1198927           1           1            0            1           0
# 1198954           0           0            0            0           1
# 1198957           1           0            0            0           1
# 1198982           1           1            0            0           1
# 1198989           0           1            0            1           0
#
#          Item 118276  Item 118299  Item 118165  Item 118103  Item 118192
# 67                 1            0            1            0            1
# 71                 1            0            0            0            0
# 118                1            0            1            0            0
# 130                1            0            1            0            0
# 198                0            1            0            1            0
# ...              ...          ...          ...          ...          ...
# 1198927            0            0            0            0            0
# 1198954            1            0            0            0            0
# 1198957            0            0            1            0            0
# 1198982            1            0            1            1            1
# 1198989            0            0            1            0            0
#
# [99632 rows x 53 columns]

# %% [markdown]
# # Low and High Incomes - English

# %%
df_alta_renda = df_gp['alta']
df_alta_renda = df_alta_renda[df_alta_renda['TP_LINGUA']==0]
df_alta_renda.drop(['NU_INSCRICAO','TP_LINGUA'], axis=1, inplace=True)
df_alta_renda.drop(item_esp, axis=1, inplace=True)
df_alta_renda = df_alta_renda[df_alta_renda['NU_NOTA_LC']!=0]
df_alta_renda.to_csv("../Data/Processed/ENEM2019/CR_data/CR_alta_renda_ing.csv")

df_baixa_renda = df_gp['baixa']
df_baixa_renda = df_baixa_renda[df_baixa_renda['TP_LINGUA']==0]
df_baixa_renda.drop(['NU_INSCRICAO','TP_LINGUA'], axis=1, inplace=True)
df_baixa_renda.drop(item_esp, axis=1, inplace=True)
df_baixa_renda = df_baixa_renda[df_baixa_renda['NU_NOTA_LC']!=0]
df_baixa_renda.to_csv("../Data/Processed/ENEM2019/CR_data/CR_baixa_renda_ing.csv")
# Out:
# /home/marcos/Documents/NewExperiments/envs/CounterCrime/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
mean_2009 = 0.0616810996437219
sd_2009 = 0.885383569242728

par_high = pd.read_csv("../Data/Processed/ENEM2019/Parameters/Parametros_CR_alta_renda_ing.csv",
                      index_col=0)
#par_high['Dffclt'] = ((par_high['Dffclt']-mean_2009)/sd_2009)*100+500
par_high.index = par_high.index.str.replace('.',' ',regex=False)
par_high = par_high.add_suffix('_high')

par_low = pd.read_csv("../Data/Processed/ENEM2019/Parameters/Parametros_CR_baixa_renda_ing.csv",
                      index_col=0)
#par_low['Dffclt'] = par_low['Dffclt']*(100/sd_2009) + 500 - 100*mean_2009/sd_2009
par_low.index = par_low.index.str.replace('.',' ',regex=False)
par_low = par_low.add_suffix('_low')
par_low['Language'] = 'Portuguese'
par_low.loc[item_ing,'Language'] = 'English'

par_income = pd.concat([par_high, par_low], axis=1)

# %%
par_income
# Out:
#              Gussng_high  Dffclt_high  Dscrmn_high  Gussng_low  Dffclt_low  \
# Item 55166      0.009723    -1.834232     0.799877    0.271763    0.688025
# Item 54110      0.002900    -1.369903     1.179197    0.156325    0.889384
# Item 23564      0.166203    -1.851325     1.883999    0.292424    0.549106
# Item 31954      0.142485    -1.954357     1.459834    0.433659    0.561992
# Item 118180     0.124848    -1.376955     1.989083    0.132803    0.804381
# Item 86563      0.025000     1.602236     0.280873    0.102220    2.627302
# Item 118161     0.009570    -1.903494     0.586311    0.001934   -0.388751
# Item 118147     0.042519    -2.344772     0.510097    0.000578   -0.782124
# Item 118118     0.067787    -0.641340     0.957785    0.151945    0.986242
# Item 118215     0.098605     0.087876     0.999757    0.158708    1.881737
# Item 118207     0.028552     0.554265     0.371443    0.012760    1.596107
# Item 118170     0.003130    -1.380734     0.288948    0.002224    0.359173
# Item 90165      0.138830     0.384429     0.812960    0.161084    1.909683
# Item 118232     0.115797     2.756402     0.376463    0.003820    4.176155
# Item 118174     0.186556     0.050400     1.331166    0.189577    1.650422
# Item 76167      0.001673    -1.673534     0.549763    0.006041    0.016837
# Item 68624      0.020640    -2.776386     0.354606    0.000954   -1.246052
# Item 96525      0.096700    -0.161272     1.312802    0.130993    1.266354
# Item 89317      0.050073    -2.174793     1.695547    0.001159   -1.198299
# Item 86496      0.002252    -1.579271     0.942435    0.004769   -0.112894
# Item 118256     0.119234     2.434660     0.582616    0.150173    3.044965
# Item 118306     0.106342     0.782653     0.941726    0.145244    1.914479
# Item 118264     0.002076    -1.639296     0.578938    0.033007    0.047645
# Item 89550      0.005834    -0.485435     0.789793    0.096747    1.345883
# Item 14169      0.098402     1.024427     0.944383    0.118782    2.199709
# Item 118235     0.131905     2.084557     0.572174    0.048491    3.623895
# Item 118117     0.164865    -1.367382     1.107267    0.003508   -0.640282
# Item 118278     0.018551     0.703732     0.680353    0.109646    2.039516
# Item 59976      0.114693    -0.617673     1.248152    0.171090    0.958009
# Item 23833      0.233800    -0.769099     1.746201    0.222523    0.681403
# Item 81992      0.021553    -0.610781     0.966865    0.102382    1.437024
# Item 32261      0.049534    -1.334546     1.637124    0.105205    0.223413
# Item 118260     0.041611    -4.002143    -1.498803    0.006413   -5.043953
# Item 118134     0.241516     0.713156     1.326200    0.194666    2.049895
# Item 89874      0.005754    -2.485324     0.900405    0.005740   -0.802169
# Item 86932      0.032706    -0.371958     0.144525    0.002814    0.395545
# Item 24785      0.028713    -2.369009     1.679138    0.000844   -1.081319
# Item 118028     0.122609     1.246922     0.912207    0.155993    2.159862
# Item 118246     0.246365     3.166720     1.446702    0.092873   34.676946
# Item 77356      0.323145     0.069607     1.521414    0.258079    1.451471
# Item 118276     0.034213    -0.348654     0.734263    0.159557    1.220256
# Item 118299     0.083124     0.838136     1.296945    0.096157    2.229816
# Item 118165     0.168556    -0.654017     0.909619    0.112246    0.477821
# Item 118103     0.140586     2.726090     1.754550    0.138456  -36.900931
# Item 118192     0.181724     2.888521     2.233533    0.015400  -15.335856
#
#              Dscrmn_low    Language
# Item 55166     1.310543     English
# Item 54110     1.968064     English
# Item 23564     2.515414     English
# Item 31954     2.516340     English
# Item 118180    2.490044     English
# Item 86563     0.399033  Portuguese
# Item 118161    0.793270  Portuguese
# Item 118147    0.656073  Portuguese
# Item 118118    1.352084  Portuguese
# Item 118215    1.725152  Portuguese
# Item 118207    0.410173  Portuguese
# Item 118170    0.946816  Portuguese
# Item 90165     1.264737  Portuguese
# Item 118232    0.207282  Portuguese
# Item 118174    1.692859  Portuguese
# Item 76167     0.967035  Portuguese
# Item 68624     0.560037  Portuguese
# Item 96525     1.796769  Portuguese
# Item 89317     1.619487  Portuguese
# Item 86496     0.922397  Portuguese
# Item 118256    1.084755  Portuguese
# Item 118306    1.373188  Portuguese
# Item 118264    0.906935  Portuguese
# Item 89550     1.100462  Portuguese
# Item 14169     1.564853  Portuguese
# Item 118235    0.329416  Portuguese
# Item 118117    0.834423  Portuguese
# Item 118278    1.371609  Portuguese
# Item 59976     1.446122  Portuguese
# Item 23833     1.675658  Portuguese
# Item 81992     1.530314  Portuguese
# Item 32261     1.644405  Portuguese
# Item 118260   -0.532107  Portuguese
# Item 118134    1.193543  Portuguese
# Item 89874     1.251406  Portuguese
# Item 86932     0.315356  Portuguese
# Item 24785     1.689654  Portuguese
# Item 118028    1.586127  Portuguese
# Item 118246    0.040623  Portuguese
# Item 77356     1.202046  Portuguese
# Item 118276    1.275246  Portuguese
# Item 118299    1.774818  Portuguese
# Item 118165    0.942698  Portuguese
# Item 118103   -0.096718  Portuguese
# Item 118192   -0.096969  Portuguese

# %%
fig, axs = plt.subplots(1, 3, figsize=(12,4))

sns.scatterplot(data=par_income,
                x="Dscrmn_low", y="Dscrmn_high", hue="Language", ax=axs[0], legend=False,
                palette=['dodgerblue','black'])
axs[0].plot([0, 3], [0, 3], color='black', ls=':')
axs[0].set_xlabel('Low Income')
axs[0].set_ylabel('High Income')
axs[0].set_title("Inclination (a)")

sns.scatterplot(data=par_income,
                x="Dffclt_low", y="Dffclt_high", hue="Language", ax=axs[1], legend=False,
                palette=['dodgerblue','black'])
axs[1].plot([0, 1], [0, 1], color='black', ls=':')
axs[1].set_xlabel('Low Income')
axs[1].set_ylabel('High Income')
axs[1].set_title("Difficulty (b)")

sns.scatterplot(data=par_income,
                x="Gussng_low", y="Gussng_high", hue="Language", ax=axs[2],
                palette=['dodgerblue','black'])
axs[2].plot([0, 0.5], [0, 0.5], color='black', ls=':')
axs[2].set_xlabel('Low Income')
axs[2].set_ylabel('High Income')
axs[2].set_title("Guessing (c)")


plt.tight_layout()
plt.show()

# %%
sns.scatterplot(data=par_income[par_income['Dffclt_low'].between(0, 1000)],
                x="Dffclt_low", y="Dffclt_high", hue="Language")
plt.plot([200, 1000], [200, 1000], color='black', ls=':')
plt.show()

# %%
hab_area_map = {'Communication Application':  [1,2,3,4],
               'Foreign Language':            [5,6,7,8], 
               'Corporal Language':           [9,10,11],
               'Art':                         [12,13,14],
               'Texts Interpretation':        [15,16,17],
               'Symbolic Systems':            [18,19,20],
               'Opinions':                    [21,22,23,24],
               'Portuguese Language':         [25,26,27],
               'Communication Technologies':  [28,29,30]
                }
area_hab_map = {}
for key in hab_area_map: 
    for item in hab_area_map[key]:
        area_hab_map[item] = key

par_income['CO_ITEM'] = par_income.index
par_income['CO_ITEM'] = par_income['CO_ITEM'].str.split().str[-1]

questoes_pd = pd.read_csv("../Data/Original/microdados_enem_"+ano+"/DADOS/ITENS_PROVA_"+ano+".csv")

for quest in list(par_income['CO_ITEM']):
    quest_cod = questoes_pd[questoes_pd['CO_ITEM']==int(quest)]['CO_HABILIDADE'].iloc[0]
    par_income.loc[par_income['CO_ITEM']==quest,'CO_HABILIDADE'] = quest_cod
    
par_income['Area'] = par_income['CO_HABILIDADE'].map(area_hab_map)
par_income
# Out:
#              Gussng_high  Dffclt_high  Dscrmn_high  Gussng_low   Dffclt_low  \
# Item 55166      0.009723   285.865390     0.799877    0.271763   570.742707
# Item 54110      0.002900   338.309194     1.179197    0.156325   593.485179
# Item 23564      0.166203   283.934763     1.883999    0.292424   555.052405
# Item 31954      0.142485   272.297764     1.459834    0.433659   556.507773
# Item 118180     0.124848   337.512670     1.989083    0.132803   583.884497
# Item 86563      0.025000   673.998575     0.280873    0.102220   789.775059
# Item 118161     0.009570   278.042510     0.586311    0.001934   449.125808
# Item 118147     0.042519   228.202231     0.510097    0.000578   404.696104
# Item 118118     0.067787   420.596968     0.957785    0.151945   604.424898
# Item 118215     0.098605   502.958578     0.999757    0.158708   705.566943
# Item 118207     0.028552   555.635099     0.371443    0.012760   673.306339
# Item 118170     0.003130   337.085863     0.288948    0.002224   533.600387
# Item 90165      0.138830   536.452921     0.812960    0.161084   708.723257
# Item 118232     0.115797   804.356284     0.376463    0.003820   964.710923
# Item 118174     0.186556   498.725873     1.331166    0.189577   679.440949
# Item 76167      0.001673   304.015405     0.549763    0.006041   494.935122
# Item 68624      0.020640   179.453391     0.354606    0.000954   352.297571
# Item 96525      0.096700   474.818468     1.312802    0.130993   636.062230
# Item 89317      0.050073   247.400502     1.695547    0.001159   357.691032
# Item 86496      0.002252   314.662038     0.942435    0.004769   480.282567
# Item 118256     0.119234   768.017096     0.582616    0.150173   836.948190
# Item 118306     0.106342   581.430492     0.941726    0.145244   709.264964
# Item 118264     0.002076   307.882414     0.578938    0.033007   498.414656
# Item 89550      0.005834   438.205810     0.789793    0.096747   645.044685
# Item 14169      0.098402   608.737711     0.944383    0.118782   741.480424
# Item 118235     0.131905   728.474507     0.572174    0.048491   902.335634
# Item 118117     0.164865   338.593888     1.107267    0.003508   420.716477
# Item 118278     0.018551   572.516641     0.680353    0.109646   723.387395
# Item 59976      0.114693   423.270136     1.248152    0.171090   601.236142
# Item 23833      0.233800   406.167244     1.746201    0.222523   569.994767
# Item 81992      0.021553   424.048493     0.966865    0.102382   655.338692
# Item 32261      0.049534   342.302541     1.637124    0.105205   518.266871
# Item 118260     0.041611    41.009754    -1.498803    0.006413   -76.657922
# Item 118134     0.241516   573.581051     1.326200    0.194666   724.559665
# Item 89874      0.005754   212.327500     0.900405    0.005740   402.432120
# Item 86932      0.032706   451.022449     0.144525    0.002814   537.708389
# Item 24785      0.028713   225.464713     1.679138    0.000844   370.903418
# Item 118028     0.122609   633.867523     0.912207    0.155993   736.979883
# Item 118246     0.246365   850.699863     1.446702    0.092873  4409.634881
# Item 77356      0.323145   500.895142     1.521414    0.258079   656.970382
# Item 118276     0.034213   453.654496     0.734263    0.159557   630.855688
# Item 118299     0.083124   587.696989     1.296945    0.096157   744.880835
# Item 118165     0.168556   419.165243     0.909619    0.112246   547.001132
# Item 118103     0.140586   800.932689     1.754550    0.138456 -3674.756898
# Item 118192     0.181724   819.278548     2.233533    0.015400 -1239.080990
#
#              Dscrmn_low    Language CO_ITEM  CO_HABILIDADE  \
# Item 55166     1.310543     English   55166            7.0
# Item 54110     1.968064     English   54110            7.0
# Item 23564     2.515414     English   23564            6.0
# Item 31954     2.516340     English   31954            8.0
# Item 118180    2.490044     English  118180            5.0
# Item 86563     0.399033  Portuguese   86563            3.0
# Item 118161    0.793270  Portuguese  118161           24.0
# Item 118147    0.656073  Portuguese  118147           23.0
# Item 118118    1.352084  Portuguese  118118            9.0
# Item 118215    1.725152  Portuguese  118215            2.0
# Item 118207    0.410173  Portuguese  118207           11.0
# Item 118170    0.946816  Portuguese  118170           23.0
# Item 90165     1.264737  Portuguese   90165           15.0
# Item 118232    0.207282  Portuguese  118232           16.0
# Item 118174    1.692859  Portuguese  118174           19.0
# Item 76167     0.967035  Portuguese   76167            1.0
# Item 68624     0.560037  Portuguese   68624           30.0
# Item 96525     1.796769  Portuguese   96525           28.0
# Item 89317     1.619487  Portuguese   89317           28.0
# Item 86496     0.922397  Portuguese   86496           30.0
# Item 118256    1.084755  Portuguese  118256           17.0
# Item 118306    1.373188  Portuguese  118306           16.0
# Item 118264    0.906935  Portuguese  118264           21.0
# Item 89550     1.100462  Portuguese   89550            1.0
# Item 14169     1.564853  Portuguese   14169           14.0
# Item 118235    0.329416  Portuguese  118235           22.0
# Item 118117    0.834423  Portuguese  118117           10.0
# Item 118278    1.371609  Portuguese  118278           16.0
# Item 59976     1.446122  Portuguese   59976           30.0
# Item 23833     1.675658  Portuguese   23833           20.0
# Item 81992     1.530314  Portuguese   81992           12.0
# Item 32261     1.644405  Portuguese   32261           24.0
# Item 118260   -0.532107  Portuguese  118260           15.0
# Item 118134    1.193543  Portuguese  118134           26.0
# Item 89874     1.251406  Portuguese   89874           10.0
# Item 86932     0.315356  Portuguese   86932           14.0
# Item 24785     1.689654  Portuguese   24785           28.0
# Item 118028    1.586127  Portuguese  118028           29.0
# Item 118246    0.040623  Portuguese  118246           17.0
# Item 77356     1.202046  Portuguese   77356           13.0
# Item 118276    1.275246  Portuguese  118276           16.0
# Item 118299    1.774818  Portuguese  118299           18.0
# Item 118165    0.942698  Portuguese  118165            4.0
# Item 118103   -0.096718  Portuguese  118103           27.0
# Item 118192   -0.096969  Portuguese  118192           25.0
#
#                                    Area
# Item 55166             Foreign Language
# Item 54110             Foreign Language
# Item 23564             Foreign Language
# Item 31954             Foreign Language
# Item 118180            Foreign Language
# Item 86563    Communication Application
# Item 118161                    Opinions
# Item 118147                    Opinions
# Item 118118           Corporal Language
# Item 118215   Communication Application
# Item 118207           Corporal Language
# Item 118170                    Opinions
# Item 90165         Texts Interpretation
# Item 118232        Texts Interpretation
# Item 118174            Symbolic Systems
# Item 76167    Communication Application
# Item 68624   Communication Technologies
# Item 96525   Communication Technologies
# Item 89317   Communication Technologies
# Item 86496   Communication Technologies
# Item 118256        Texts Interpretation
# Item 118306        Texts Interpretation
# Item 118264                    Opinions
# Item 89550    Communication Application
# Item 14169                          Art
# Item 118235                    Opinions
# Item 118117           Corporal Language
# Item 118278        Texts Interpretation
# Item 59976   Communication Technologies
# Item 23833             Symbolic Systems
# Item 81992                          Art
# Item 32261                     Opinions
# Item 118260        Texts Interpretation
# Item 118134         Portuguese Language
# Item 89874            Corporal Language
# Item 86932                          Art
# Item 24785   Communication Technologies
# Item 118028  Communication Technologies
# Item 118246        Texts Interpretation
# Item 77356                          Art
# Item 118276        Texts Interpretation
# Item 118299            Symbolic Systems
# Item 118165   Communication Application
# Item 118103         Portuguese Language
# Item 118192         Portuguese Language

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=par_income[par_income['Dffclt_low'].between(0, 1000)],
                x="Dffclt_low", y="Dffclt_high", hue="Area")
plt.plot([200, 1000], [200, 1000], color='black', ls=':')
plt.xlabel('Low Income')
plt.ylabel('High Income')
plt.title("Comparision of difficulty (b) by area")
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12,4))

sns.scatterplot(data=par_income[par_income['Dffclt_low'].between(0, 1000)],
                x="Dscrmn_low", y="Dscrmn_high", hue="Area", ax=axs[0], legend=False)
axs[0].plot([0, 3], [0, 3], color='black', ls=':')
axs[0].set_xlabel('Low Income')
axs[0].set_ylabel('High Income')
axs[0].set_title("Inclination (a)")

sns.scatterplot(data=par_income[par_income['Dffclt_low'].between(0, 1000)],
                x="Dffclt_low", y="Dffclt_high", hue="Area", ax=axs[1], legend=False)
axs[1].plot([200, 1000], [200, 1000], color='black', ls=':')
axs[1].set_xlabel('Low Income')
axs[1].set_ylabel('High Income')
axs[1].set_title("Difficulty (b)")

sns.scatterplot(data=par_income[par_income['Dffclt_low'].between(0, 1000)],
                x="Gussng_low", y="Gussng_high", hue="Area", ax=axs[2])
axs[2].plot([0, 0.5], [0, 0.5], color='black', ls=':')
axs[2].set_xlabel('Low Income')
axs[2].set_ylabel('High Income')
axs[2].set_title("Guessing (c)")


plt.tight_layout()
plt.show()
