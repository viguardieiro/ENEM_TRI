# %% [markdown]
# # Compare Economic Class ENEM 2019

# %%
import pandas as pd
from CompareGroupsFunctions import *

ano = '2019'
gp_feat = 'CLASSE'
gp_name = 'classe'
gp_map = {'E': 'Classe E',
          'D': 'Classe D',
          'C': 'Classe C',
          'B': 'Classe B',
          'A': 'Classe A'}

# %% [markdown]
# ## 1. Ciências Humanas

# %%
ch_comp = GroupComparator(comp='CH', ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
df_gp = ch_comp.get_df_gp()
ch_comp.print_mean_std()
# Out:
# Média e Std por classe:
# Classe E - Média: 482.95;   Std: 73.82
# Classe D - Média: 520.81;   Std: 75.52
# Classe C - Média: 556.29;   Std: 75.43
# Classe B - Média: 592.80;   Std: 70.59
# Classe A - Média: 608.10;   Std: 68.68
# Geral - Média: 506.10;   Std: 81.10

# %%
ch_comp.plot_hist_scores()

# %%
bin_ch = ch_comp.bin_scores(nota_min=300, nota_max=800, step=20)
auc_ch = ch_comp.auc_groups()
sorted_auc_dif_ch = ch_comp.sort_abs_auc_dif()
# Out:
# Item 33960     0.006949
# Item 97975     0.007762
# Item 76955     0.008696
# Item 83820     0.009176
# Item 84888     0.013048
# Item 84769     0.013214
# Item 118034    0.019257
# Item 111877    0.019532
# Item 78903     0.020013
# Item 85139     0.021707
# Item 118108    0.022960
# Item 66498     0.023128
# Item 97013     0.028902
# Item 11601     0.029058
# Item 96302     0.029998
# Item 87709     0.030370
# Item 118024    0.030706
# Item 86934     0.031528
# Item 118158    0.035310
# Item 112135    0.036103
# Item 95648     0.036600
# Item 118125    0.038914
# Item 77940     0.042068
# Item 118029    0.042568
# Item 88194     0.042786
# Item 88308     0.044252
# Item 96596     0.045276
# Item 111844    0.050227
# Item 88306     0.051124
# Item 89147     0.053231
# Item 87057     0.055695
# Item 88233     0.056671
# Item 118038    0.058093
# Item 84147     0.059244
# Item 118033    0.059248
# Item 118022    0.064930
# Item 81689     0.067851
# Item 111820    0.068186
# Item 84811     0.075273
# Item 86751     0.080716
# Item 96447     0.082626
# Item 66219     0.107813
# Item 111894    0.110200
# Item 118054    0.113371
# Item 118067    0.136568
# dtype: float64

# %%
ch_comp.plot_item_compar(item = 'Item 118067')

# %%
ch_comp.plot_item_compar(item = 'Item 118054')

# %% [markdown]
# ## 2. Ciências da Natureza

# %%
cn_comp = GroupComparator(comp='CN', ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
df_gp = cn_comp.get_df_gp()
cn_comp.print_mean_std()
# Out:
# Média e Std por classe:
# Classe E - Média: 453.43;   Std: 64.72
# Classe D - Média: 488.58;   Std: 72.16
# Classe C - Média: 527.05;   Std: 75.25
# Classe B - Média: 565.91;   Std: 71.88
# Classe A - Média: 578.81;   Std: 72.75
# Geral - Média: 476.48;   Std: 75.76

# %%
cn_comp.plot_hist_scores()

# %%
bin_cn = cn_comp.bin_scores(nota_min=300, nota_max=760, step=20)
auc_cn = cn_comp.auc_groups()
sorted_auc_dif_cn = cn_comp.sort_abs_auc_dif()
# Out:
# Item 29776     0.011201
# Item 96556     0.011312
# Item 86521     0.012377
# Item 7529      0.015537
# Item 111601    0.017487
# Item 117988    0.019232
# Item 19223     0.019501
# Item 81478     0.020752
# Item 89515     0.023488
# Item 85548     0.026873
# Item 24104     0.032982
# Item 19407     0.033164
# Item 89150     0.033480
# Item 117642    0.033569
# Item 39290     0.037712
# Item 7629      0.039243
# Item 117979    0.039960
# Item 31718     0.045270
# Item 111705    0.046532
# Item 84568     0.050512
# Item 83526     0.051768
# Item 89298     0.051832
# Item 111545    0.057319
# Item 78504     0.057366
# Item 117883    0.057924
# Item 88853     0.064460
# Item 55328     0.066647
# Item 60311     0.068669
# Item 82236     0.072178
# Item 83609     0.072776
# Item 111624    0.074823
# Item 82364     0.078489
# Item 54381     0.080804
# Item 14273     0.085400
# Item 117746    0.086484
# Item 117999    0.094148
# Item 83441     0.095890
# Item 89772     0.098397
# Item 82490     0.100719
# Item 117890    0.121469
# Item 117836    0.122000
# Item 97169     0.122209
# Item 49600     0.123607
# Item 117875    0.129869
# Item 117868    0.180692
# dtype: float64

# %%
cn_comp.plot_item_compar(item = 'Item 117868')

# %%
cn_comp.plot_item_compar(item = 'Item 117875')

# %% [markdown]
# ## 3. Matemática

# %%
mt_comp = GroupComparator(comp='MT', ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
df_gp = mt_comp.get_df_gp()
mt_comp.print_mean_std()
# Out:
# Média e Std por classe:
# Classe E - Média: 493.04;   Std: 87.93
# Classe D - Média: 544.79;   Std: 103.73
# Classe C - Média: 602.74;   Std: 113.87
# Classe B - Média: 665.61;   Std: 113.16
# Classe A - Média: 696.41;   Std: 110.86
# Geral - Média: 527.62;   Std: 108.81

# %%
mt_comp.plot_hist_scores()

# %%
bin_mt = mt_comp.bin_scores(nota_min=360, nota_max=800, step=20)
auc_mt = mt_comp.auc_groups()
sorted_auc_dif_mt = mt_comp.sort_abs_auc_dif()
# Out:
# Item 117743    0.011540
# Item 63187     0.012199
# Item 111593    0.012782
# Item 117783    0.013866
# Item 117818    0.014228
# Item 111696    0.018181
# Item 83955     0.019791
# Item 13303     0.025887
# Item 117845    0.028692
# Item 111608    0.030634
# Item 117635    0.032799
# Item 30740     0.037567
# Item 30436     0.039283
# Item 117950    0.039848
# Item 117607    0.041804
# Item 31184     0.044374
# Item 30570     0.044527
# Item 84374     0.045296
# Item 111518    0.045307
# Item 8368      0.047600
# Item 8401      0.047827
# Item 83792     0.049897
# Item 117798    0.053397
# Item 54448     0.059477
# Item 28434     0.066101
# Item 117767    0.068799
# Item 39708     0.070461
# Item 117725    0.071688
# Item 14324     0.072584
# Item 89634     0.072950
# Item 17642     0.073668
# Item 42803     0.075203
# Item 117612    0.075618
# Item 86432     0.078593
# Item 9779      0.084327
# Item 8442      0.089632
# Item 23065     0.091214
# Item 10360     0.101576
# Item 63808     0.105129
# Item 83754     0.112337
# Item 18002     0.120447
# Item 84409     0.135308
# Item 83994     0.136125
# Item 78445     0.193492
# Item 117726    0.245607
# dtype: float64

# %%
mt_comp.plot_item_compar(item = 'Item 117726')

# %%
mt_comp.plot_item_compar(item = 'Item 78445')

# %%
mt_comp.plot_item_compar(item = 'Item 83994')

# %% [markdown]
# ## 4. Linguagens e Códigos

# %%
comp = 'LC'

lc_comp = GroupComparator(comp=comp, ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
df_gp = lc_comp.get_df_gp()

item_ing = ['Item 55166', 'Item 54110', 'Item 23564', 'Item 31954', 'Item 118180']
item_esp = ['Item 96705', 'Item 118222','Item 39016', 'Item 118167', 'Item 48558']

df_gp_ing = {}
df_gp_esp = {}
df_gp_pt = {}

for g in df_gp.keys():
    df_gp_ing[g] = df_gp[g][df_gp[g]['TP_LINGUA']==0][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_esp[g] = df_gp[g][df_gp[g]['TP_LINGUA']==1][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_pt[g] = df_gp[g][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    
    for col in df_gp[list(df_gp.keys())[0]].columns:
        if col in item_ing:
            df_gp_ing[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==0][col]
        elif col in item_esp:
            df_gp_esp[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==1][col]
        elif col!='NU_INSCRICAO' and col!='NU_NOTA_LC' and col!='TP_LINGUA':
            df_gp_pt[g][col] = df_gp[g][col]

# %% [markdown]
# ### 4.1 Inglês

# %%
print("Proporção de participantes em inglês:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em inglês:
# Classe E: 0.447
# Classe D: 0.613
# Classe C: 0.735
# Classe B: 0.866
# Classe A: 0.912
# Geral: 0.541

# %%
lc_comp_ing = GroupComparator(comp=comp, ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
lc_comp_ing.df_gp = df_gp_ing
lc_comp_ing.print_mean_std()
# Out:
# Média e Std por classe:
# Classe E - Média: 512.54;   Std: 61.41
# Classe D - Média: 543.02;   Std: 55.29
# Classe C - Média: 567.62;   Std: 51.33
# Classe B - Média: 588.34;   Std: 46.46
# Classe A - Média: 596.32;   Std: 44.45
# Geral - Média: 535.69;   Std: 62.79

# %%
lc_comp_ing.plot_hist_scores()

# %%
bin_lc_ing = lc_comp_ing.bin_scores(nota_min=350, nota_max=750)
auc_lc_ing = lc_comp_ing.auc_groups()
sorted_auc_dif_lc_ing = lc_comp_ing.sort_abs_auc_dif()
# Out:
# Item 31954     0.115620
# Item 55166     0.118842
# Item 54110     0.196062
# Item 23564     0.217332
# Item 118180    0.340120
# dtype: float64

# %%
lc_comp_ing.plot_item_compar(item = 'Item 118180')

# %%
lc_comp_ing.plot_item_compar(item = 'Item 23564')

# %%
lc_comp_ing.plot_item_compar(item = 'Item 54110')

# %%
lc_comp_ing.plot_item_compar(item = 'Item 31954')

# %% [markdown]
# ### 4.2 Espanhol

# %%
print("Proporção de participantes em espanhol:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em espanhol:
# Classe E: 0.553
# Classe D: 0.387
# Classe C: 0.265
# Classe B: 0.134
# Classe A: 0.088
# Geral: 0.459

# %%
lc_comp_esp = GroupComparator(comp=comp, ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
lc_comp_esp.df_gp = df_gp_esp
lc_comp_esp.print_mean_std()
# Out:
# Média e Std por classe:
# Classe E - Média: 491.13;   Std: 59.71
# Classe D - Média: 517.91;   Std: 56.00
# Classe C - Média: 534.13;   Std: 54.73
# Classe B - Média: 548.90;   Std: 55.22
# Classe A - Média: 549.18;   Std: 56.82
# Geral - Média: 500.14;   Std: 60.59

# %%
lc_comp_esp.plot_hist_scores()

# %%
bin_lc_esp = lc_comp_esp.bin_scores(nota_min=350, nota_max=750)
auc_lc_esp = lc_comp_esp.auc_groups()
sorted_auc_dif_lc_esp = lc_comp_esp.sort_abs_auc_dif()
# Out:
# Item 96705     0.074912
# Item 39016     0.081311
# Item 118167    0.084014
# Item 48558     0.087835
# Item 118222    0.129862
# dtype: float64

# %%
lc_comp_esp.plot_item_compar(item = 'Item 118222')

# %% [markdown]
# ### 4.3 Português

# %%
lc_comp_pt = GroupComparator(comp=comp, ano=ano, gp_feat=gp_feat, gp_name=gp_name, gp_map=gp_map)
lc_comp_pt.df_gp = df_gp_pt
lc_comp_pt.print_mean_std()
# Out:
# Média e Std por classe:
# Classe E - Média: 500.69;   Std: 61.40
# Classe D - Média: 533.30;   Std: 56.90
# Classe C - Média: 558.74;   Std: 54.30
# Classe B - Média: 583.06;   Std: 49.58
# Classe A - Média: 592.17;   Std: 47.59
# Geral - Média: 519.36;   Std: 64.28

# %%
lc_comp_pt.plot_hist_scores()

# %%
bin_lc_pt = lc_comp_pt.bin_scores(nota_min=350, nota_max=750)
auc_lc_pt = lc_comp_pt.auc_groups()
sorted_auc_dif_lc_pt = lc_comp_pt.sort_abs_auc_dif()
# Out:
# Item 23833     0.009774
# Item 59976     0.014133
# Item 96525     0.016208
# Item 89874     0.021113
# Item 77356     0.022427
# Item 118276    0.022543
# Item 14169     0.022889
# Item 118147    0.024116
# Item 24785     0.024155
# Item 32261     0.027703
# Item 86496     0.028252
# Item 118306    0.032880
# Item 118235    0.035338
# Item 118118    0.036350
# Item 118174    0.039130
# Item 118161    0.041957
# Item 76167     0.042690
# Item 118117    0.044419
# Item 118134    0.045073
# Item 118028    0.045289
# Item 118165    0.046182
# Item 118207    0.046292
# Item 118264    0.048542
# Item 86932     0.048844
# Item 118232    0.051361
# Item 86563     0.052949
# Item 118278    0.055771
# Item 118246    0.059184
# Item 118170    0.067209
# Item 89550     0.072797
# Item 118299    0.079861
# Item 118192    0.080985
# Item 118260    0.085147
# Item 118256    0.087597
# Item 90165     0.087736
# Item 68624     0.088748
# Item 118215    0.097914
# Item 89317     0.102046
# Item 118103    0.102680
# Item 81992     0.157412
# dtype: float64

# %%
lc_comp_pt.plot_item_compar(item = 'Item 81992')

# %%
lc_comp_pt.plot_item_compar(item = 'Item 118103')
