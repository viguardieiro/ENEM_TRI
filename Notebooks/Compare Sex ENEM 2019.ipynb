# %% [markdown]
# # Compare Sex - ENEM 2019

# %%
import pandas as pd
from CompareGroupsFunctions import *

ano = '2019'

# %% [markdown]
# ## 1. Ciências Humanas

# %%
ch_comp = GroupComparator(comp='CH', ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
df_gp = ch_comp.get_df_gp()
ch_comp.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 512.31;   Std: 84.10
# Feminino - Média: 501.64;   Std: 78.57
# Geral - Média: 506.10;   Std: 81.10

# %%
ch_comp.plot_hist_scores_2groups()

# %%
bin_ch = ch_comp.bin_scores()
auc_ch = ch_comp.auc_groups()
sorted_auc_dif_ch = ch_comp.sort_abs_auc_dif()
# Out:
# Item 84888     0.021946
# Item 66219     0.027130
# Item 66498     0.033499
# Item 87057     0.036324
# Item 95648     0.038380
# Item 84147     0.040421
# Item 118067    0.046266
# Item 111877    0.078781
# Item 77940     0.105054
# Item 97975     0.140251
# Item 83820     0.155767
# Item 86934     0.158669
# Item 84769     0.211828
# Item 84811     0.215653
# Item 96447     0.222741
# Item 88194     0.226374
# Item 111844    0.233085
# Item 88306     0.244164
# Item 78903     0.248113
# Item 118024    0.271085
# Item 96302     0.274392
# Item 86751     0.320015
# Item 88233     0.332498
# Item 118108    0.335266
# Item 11601     0.339128
# Item 111894    0.349023
# Item 89147     0.360618
# Item 111820    0.364618
# Item 118038    0.401252
# Item 81689     0.424061
# Item 118125    0.479628
# Item 87709     0.491159
# Item 96596     0.503659
# Item 118022    0.518666
# Item 88308     0.559094
# Item 33960     0.589665
# Item 76955     0.606003
# Item 118033    0.619363
# Item 85139     0.637010
# Item 97013     0.674853
# Item 112135    0.783594
# Item 118029    0.834901
# Item 118158    0.851235
# Item 118034    1.120813
# Item 118054    1.581506
# dtype: float64

# %%
ch_comp.plot_item_compar(item = 'Item 118034')

# %%
ch_comp.plot_item_compar(item = 'Item 118054')

# %% [markdown]
# ## 2. Ciências da Natureza

# %%
cn_comp = GroupComparator(comp='CN', ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
df_gp = cn_comp.get_df_gp()
cn_comp.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 487.69;   Std: 78.05
# Feminino - Média: 468.38;   Std: 73.01
# Geral - Média: 476.48;   Std: 75.76

# %%
cn_comp.plot_hist_scores_2groups()

# %%
bin_cn = cn_comp.bin_scores()
auc_cn = cn_comp.auc_groups()
sorted_auc_dif_cn = cn_comp.sort_abs_auc_dif()
# Out:
# Item 7529      0.040447
# Item 85548     0.043168
# Item 117883    0.047984
# Item 19407     0.065779
# Item 89515     0.066266
# Item 89772     0.069406
# Item 111601    0.086773
# Item 111545    0.097963
# Item 89150     0.117510
# Item 54381     0.127791
# Item 31718     0.155796
# Item 117875    0.164326
# Item 78504     0.184521
# Item 117979    0.203572
# Item 19223     0.249714
# Item 117642    0.252948
# Item 117868    0.261004
# Item 14273     0.263878
# Item 88853     0.270866
# Item 82236     0.285167
# Item 83441     0.310845
# Item 117999    0.318599
# Item 81478     0.322869
# Item 117890    0.352368
# Item 82364     0.352746
# Item 97169     0.400207
# Item 49600     0.406046
# Item 86521     0.415000
# Item 96556     0.421906
# Item 82490     0.427419
# Item 111624    0.480665
# Item 117746    0.487968
# Item 60311     0.531343
# Item 117988    0.559367
# Item 55328     0.601850
# Item 83526     0.637101
# Item 89298     0.670826
# Item 83609     0.704781
# Item 111705    0.708759
# Item 29776     0.866883
# Item 24104     0.902047
# Item 39290     0.906840
# Item 84568     0.974280
# Item 7629      1.280969
# Item 117836    2.435934
# dtype: float64

# %%
cn_comp.plot_item_compar(item = 'Item 39290')

# %%
cn_comp.plot_item_compar(item = 'Item 84568')

# %%
cn_comp.plot_item_compar(item = 'Item 7629')

# %%
cn_comp.plot_item_compar(item = 'Item 117836')

# %% [markdown]
# ## 3. Matemática

# %%
mt_comp = GroupComparator(comp='MT', ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
df_gp = mt_comp.get_df_gp()
mt_comp.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 550.57;   Std: 115.94
# Feminino - Média: 511.04;   Std: 100.13
# Geral - Média: 527.62;   Std: 108.81

# %%
mt_comp.plot_hist_scores_2groups()

# %%
bin_mt = mt_comp.bin_scores(nota_min=350, nota_max=800)
auc_mt = mt_comp.auc_groups()
sorted_auc_dif_mt = mt_comp.sort_abs_auc_dif()
# Out:
# Item 42803     0.007466
# Item 8401      0.031586
# Item 84374     0.036422
# Item 117612    0.045358
# Item 111593    0.071988
# Item 30740     0.082211
# Item 17642     0.083158
# Item 13303     0.088486
# Item 39708     0.088810
# Item 30570     0.097780
# Item 117950    0.104599
# Item 83955     0.105273
# Item 83754     0.117971
# Item 78445     0.123907
# Item 117607    0.136371
# Item 117818    0.140594
# Item 111696    0.168286
# Item 23065     0.178575
# Item 8442      0.180093
# Item 30436     0.185166
# Item 117725    0.193830
# Item 83994     0.197443
# Item 117767    0.224104
# Item 117726    0.251635
# Item 117845    0.264276
# Item 18002     0.269651
# Item 89634     0.295956
# Item 111518    0.299916
# Item 117783    0.315281
# Item 14324     0.348464
# Item 9779      0.354929
# Item 117798    0.399026
# Item 63808     0.421462
# Item 10360     0.528293
# Item 111608    0.631950
# Item 28434     0.660850
# Item 8368      0.688785
# Item 83792     0.881655
# Item 54448     0.917723
# Item 86432     0.921278
# Item 84409     1.011722
# Item 117743    1.032557
# Item 63187     1.081924
# Item 31184     1.254974
# Item 117635    1.614734
# dtype: float64

# %%
mt_comp.plot_item_compar(item = 'Item 117743')

# %%
mt_comp.plot_item_compar(item = 'Item 63187')

# %%
mt_comp.plot_item_compar(item = 'Item 31184')

# %%
mt_comp.plot_item_compar(item = 'Item 117635')

# %% [markdown]
# ## 4. Linguagens e Códigos

# %%
comp = 'LC'

lc_comp = GroupComparator(comp=comp, ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
df_gp = lc_comp.get_df_gp()

item_ing = ['Item 55166', 'Item 54110', 'Item 23564', 'Item 31954', 'Item 118180']
item_esp = ['Item 96705', 'Item 118222','Item 39016', 'Item 118167', 'Item 48558']

df_gp_ing = {}
df_gp_esp = {}
df_gp_pt = {}

for g in df_gp.keys():
    df_gp_ing[g] = df_gp[g][df_gp[g]['TP_LINGUA']==0][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_esp[g] = df_gp[g][df_gp[g]['TP_LINGUA']==1][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_pt[g] = df_gp[g][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    
    for col in df_gp[list(df_gp.keys())[0]].columns:
        if col in item_ing:
            df_gp_ing[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==0][col]
        elif col in item_esp:
            df_gp_esp[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==1][col]
        elif col!='NU_INSCRICAO' and col!='NU_NOTA_LC' and col!='TP_LINGUA':
            df_gp_pt[g][col] = df_gp[g][col]

# %% [markdown]
# ### 4.1 Inglês

# %%
print("Proporção de participantes em inglês:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em inglês:
# Masculino: 0.594
# Feminino: 0.502
# Geral: 0.541

# %%
lc_comp_ing = GroupComparator(comp=comp, ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
lc_comp_ing.df_gp = df_gp_ing
lc_comp_ing.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 536.05;   Std: 64.22
# Feminino - Média: 535.39;   Std: 61.54
# Geral - Média: 535.69;   Std: 62.79

# %%
lc_comp_ing.plot_hist_scores_2groups()

# %%
bin_lc_ing = lc_comp_ing.bin_scores(nota_min=350, nota_max=700)
auc_lc_ing = lc_comp_ing.auc_groups()
sorted_auc_dif_lc_ing = lc_comp_ing.sort_abs_auc_dif()
# Out:
# Item 23564     0.072961
# Item 54110     0.135466
# Item 55166     0.206068
# Item 31954     0.289593
# Item 118180    0.340919
# dtype: float64

# %%
lc_comp_ing.plot_item_compar(item = 'Item 118180')

# %% [markdown]
# ### 4.2 Espanhol

# %%
print("Proporção de participantes em espanhol:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em espanhol:
# Masculino: 0.406
# Feminino: 0.498
# Geral: 0.459

# %%
lc_comp_esp = GroupComparator(comp=comp, ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
lc_comp_esp.df_gp = df_gp_esp
lc_comp_esp.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 494.97;   Std: 64.40
# Feminino - Média: 503.16;   Std: 58.03
# Geral - Média: 500.14;   Std: 60.59

# %%
lc_comp_esp.plot_hist_scores_2groups()

# %%
bin_lc_esp = lc_comp_esp.bin_scores(nota_min=350, nota_max=700)
auc_lc_esp = lc_comp_esp.auc_groups()
sorted_auc_dif_lc_esp = lc_comp_esp.sort_abs_auc_dif()
# Out:
# Item 118167    0.180023
# Item 96705     0.287327
# Item 118222    0.426765
# Item 39016     0.598517
# Item 48558     0.809423
# dtype: float64

# %%
lc_comp_esp.plot_item_compar(item = 'Item 48558')

# %% [markdown]
# ### 4.3 Português

# %%
lc_comp_pt = GroupComparator(comp=comp, ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
lc_comp_pt.df_gp = df_gp_pt
lc_comp_pt.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 519.39;   Std: 67.39
# Feminino - Média: 519.34;   Std: 61.95
# Geral - Média: 519.36;   Std: 64.28

# %%
lc_comp_pt.plot_hist_scores_2groups()

# %%
bin_lc_pt = lc_comp_pt.bin_scores(nota_min=350, nota_max=700)
auc_lc_pt = lc_comp_pt.auc_groups()
sorted_auc_dif_lc_pt = lc_comp_pt.sort_abs_auc_dif()
# Out:
# Item 118161    0.015576
# Item 118256    0.016287
# Item 23833     0.018961
# Item 118215    0.023101
# Item 81992     0.077410
# Item 118246    0.103873
# Item 118170    0.103983
# Item 89550     0.133957
# Item 118260    0.136808
# Item 118174    0.137855
# Item 14169     0.142321
# Item 118103    0.146050
# Item 118192    0.150267
# Item 118207    0.157288
# Item 118299    0.180820
# Item 86496     0.185585
# Item 90165     0.192746
# Item 118165    0.196524
# Item 118147    0.197997
# Item 86563     0.212780
# Item 32261     0.258649
# Item 118276    0.259988
# Item 24785     0.275280
# Item 118306    0.316108
# Item 77356     0.331267
# Item 118117    0.386302
# Item 118118    0.402993
# Item 118278    0.413750
# Item 118264    0.424478
# Item 118235    0.446158
# Item 59976     0.469616
# Item 118028    0.486765
# Item 118232    0.514201
# Item 89317     0.541153
# Item 86932     0.607967
# Item 76167     0.696344
# Item 96525     0.810781
# Item 68624     0.876283
# Item 118134    0.919619
# Item 89874     1.801855
# dtype: float64

# %%
lc_comp_pt.plot_item_compar(item = 'Item 118134')

# %%
lc_comp_pt.plot_item_compar(item = 'Item 89874')
