# %% [markdown]
# # Compare Regions - ENEM 2019

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from CompareRegionsFunctions import *

ano = '2019'

# %% [markdown]
# ## 1. Ciências Humanas

# %%
comp = 'CH'
df_reg = get_df_reg(comp, ano)
print_mean_std(df_reg, comp)
# Out:
# N - Média: 482.43;   Std: 76.76
# NE - Média: 487.95;   Std: 80.46
# SE - Média: 520.80;   Std: 79.79
# S - Média: 522.98;   Std: 77.00
# CO - Média: 507.65;   Std: 79.72
# Geral - Média: 506.10;   Std: 81.10

# %%
plot_hist_scores(df_reg, comp)

# %%
questoes_list = list(df_reg['N'].columns[2:])

bin_reg = bin_scores(df_reg, comp, questoes_list, nota_min=300, nota_max=760, step=20)
auc_reg = auc_regions(bin_reg, questoes_list)

auc_reg
# Out:
#                      N         NE         SE          S         CO      Geral
# Item 111894   8.405755   8.597449   8.189937   8.302186   8.237148   8.323319
# Item 118054   6.089087   6.534351   6.371212   6.261607   6.598059   6.405959
# Item 118067   4.006512   3.858402   3.758811   3.733849   3.599072   3.804108
# Item 66498   10.738056  10.669845  10.848183  10.503940  10.841842  10.709633
# Item 86751    5.628484   5.353899   5.126530   4.971020   5.329743   5.215511
# Item 83820   13.135464  13.085906  13.046494  12.908083  13.029716  13.042855
# Item 77940   13.712541  13.456564  13.195294  13.435316  13.642958  13.425185
# Item 118034   8.970153   9.171760   9.587171   9.748061   9.152802   9.423033
# Item 84888    7.380753   7.373045   7.524884   7.038334   7.389695   7.436304
# Item 88233    7.170368   6.914788   7.375760   7.511305   7.315843   7.301009
# Item 86934    8.473094   8.327771   8.709559   8.829666   8.627491   8.617787
# ...

# %%
sort_abs_auc_dif(auc_reg)
# Out:
# Item 85139     0.057163
# Item 111877    0.136690
# Item 83820     0.138411
# Item 33960     0.139781
# Item 81689     0.146476
# Item 111844    0.153420
# Item 96302     0.163356
# Item 111820    0.177010
# Item 78903     0.177673
# Item 11601     0.179706
# Item 88308     0.185221
# Item 118038    0.197666
# Item 112135    0.198687
# Item 118067    0.205036
# Item 84769     0.243935
# Item 97013     0.251662
# Item 77940     0.261270
# Item 118024    0.269843
# Item 96447     0.279755
# Item 87709     0.282615
# Item 89147     0.290494
# Item 97975     0.305948
# Item 95648     0.308022
# Item 118033    0.311078
# Item 118108    0.329298
# Item 66498     0.344243
# Item 118022    0.344702
# Item 87057     0.355241
# Item 86751     0.358723
# Item 118125    0.369411
# Item 96596     0.374548
# Item 86934     0.381788
# Item 84811     0.383228
# Item 111894    0.407513
# Item 118054    0.445264
# Item 84147     0.445684
# Item 88233     0.460972
# Item 84888     0.486550
# ...

# %%
plot_item_compar(bin_reg, comp, item = 'Item 118158')

# %%
plot_item_compar(bin_reg, comp, item = 'Item 76955')

# %% [markdown]
# ## 2. Ciências da Natureza

# %%
comp = 'CN'
df_reg = get_df_reg(comp, ano)
print_mean_std(df_reg, comp)
# Out:
# N - Média: 454.31;   Std: 68.25
# NE - Média: 460.72;   Std: 72.53
# SE - Média: 490.53;   Std: 76.63
# S - Média: 488.05;   Std: 74.93
# CO - Média: 479.44;   Std: 75.68
# Geral - Média: 476.48;   Std: 75.76

# %%
plot_hist_scores(df_reg, comp)

# %%
questoes_list = list(df_reg['N'].columns[2:])

bin_reg = bin_scores(df_reg, comp, questoes_list, nota_min=300, nota_max=760, step=20)
auc_reg = auc_regions(bin_reg, questoes_list)

auc_reg
# Out:
#                      N         NE         SE          S         CO      Geral
# Item 82364    8.570459   8.466139   8.912590   8.848907   8.721249   8.735879
# Item 117836   6.338615   5.911586   5.485489   6.117464   6.273638   5.779421
# Item 29776   13.107582  13.076638  13.145968  13.175382  13.264062  13.132936
# Item 117999  10.971322  10.845212  11.410385  11.726737  11.135393  11.227275
# Item 117746   4.757229   4.755823   4.545864   4.126657   4.119755   4.525638
# Item 86521   12.029673  11.944807  12.013544  12.340033  12.068041  12.041663
# Item 31718   12.359020  11.985163  12.059730  11.702794  12.145035  12.057190
# Item 89150   11.998167  12.062783  12.518690  12.579333  12.242610  12.313530
# Item 117988   9.107217   8.645733   8.919169   8.857437   8.799865   8.864233
# Item 7529    12.115386  12.444109  12.239777  11.907208  12.274256  12.246442
# Item 88853   10.516426  10.428616  10.168717  10.159966  10.328037  10.291538
# ...

# %%
sort_abs_auc_dif(auc_reg)
# Out:
# Item 111601    0.037351
# Item 117979    0.083226
# Item 19223     0.119375
# Item 29776     0.131126
# Item 89515     0.136766
# Item 81478     0.140679
# Item 83526     0.152699
# Item 7629      0.166545
# Item 117890    0.177188
# Item 60311     0.186464
# Item 111705    0.218261
# Item 83441     0.236392
# Item 88853     0.259899
# Item 39290     0.288070
# Item 78504     0.306298
# Item 83609     0.307718
# Item 111545    0.324220
# Item 86521     0.326489
# Item 117642    0.332053
# Item 7529      0.367048
# Item 117883    0.367476
# Item 117875    0.377082
# Item 96556     0.391084
# Item 117868    0.396190
# Item 82490     0.409280
# Item 55328     0.410370
# Item 117746    0.419207
# Item 97169     0.420063
# Item 31718     0.442242
# Item 111624    0.442512
# Item 82364     0.446451
# Item 89150     0.455907
# Item 117988    0.461484
# Item 82236     0.463606
# Item 19407     0.467748
# Item 49600     0.493965
# Item 24104     0.515358
# Item 54381     0.584174
# ...

# %%
plot_item_compar(bin_reg, comp, item = 'Item 84568')

# %%
plot_item_compar(bin_reg, comp, item = 'Item 89772')

# %% [markdown]
# ## 3. Matemática

# %%
comp = 'MT'

df_reg = get_df_reg(comp, ano)
print_mean_std(df_reg, comp)
# Out:
# N - Média: 489.99;   Std: 90.96
# NE - Média: 506.39;   Std: 102.50
# SE - Média: 548.29;   Std: 112.53
# S - Média: 546.26;   Std: 108.20
# CO - Média: 527.56;   Std: 107.11
# Geral - Média: 527.62;   Std: 108.81

# %%
plot_hist_scores(df_reg, comp)

# %%
questoes_list = list(df_reg['N'].columns[2:])

bin_reg = bin_scores(df_reg, comp, questoes_list, nota_min=300, nota_max=760, step=20)
auc_reg = auc_regions(bin_reg, questoes_list)

auc_reg
# Out:
#                      N         NE         SE          S         CO      Geral
# Item 117635  12.050828  11.437725  11.763870  12.148723  11.773507  11.733138
# Item 9779     2.777579   2.774108   2.762014   2.533141   2.774722   2.753177
# Item 111608   3.792185   3.889557   4.009108   4.194681   3.989416   4.000547
# Item 111696   6.745934   6.606793   6.908025   6.677224   6.545653   6.751448
# Item 63187   11.538242  11.542343  11.201951  11.223834  11.557213  11.355349
# Item 117612   3.801061   3.744834   3.532996   3.528634   3.675566   3.612795
# Item 63808    2.986921   2.915253   2.725543   2.541996   2.816564   2.781252
# Item 54448    8.480226   8.362945   8.600674   8.876135   8.537949   8.546781
# Item 86432   12.582880  12.462749  12.663027  12.687385  12.596197  12.602975
# Item 23065    2.964249   2.922770   2.855400   2.871437   2.850032   2.886409
# Item 117798   3.098572   3.248770   3.025792   3.022782   3.047559   3.067791
# ...

# %%
sort_abs_auc_dif(auc_reg)
# Out:
# Item 117818    0.053369
# Item 17642     0.067268
# Item 23065     0.067369
# Item 117845    0.090175
# Item 89634     0.107678
# Item 117607    0.112484
# Item 8401      0.115005
# Item 117783    0.115289
# Item 28434     0.116950
# Item 39708     0.133797
# Item 84374     0.139590
# Item 10360     0.146996
# Item 117950    0.164778
# Item 14324     0.168646
# Item 8442      0.177399
# Item 117726    0.181881
# Item 13303     0.182985
# Item 83754     0.190374
# Item 83955     0.198007
# Item 86432     0.200279
# Item 111593    0.204190
# Item 111608    0.205265
# Item 117612    0.211838
# Item 117798    0.222978
# Item 117725    0.227522
# Item 9779      0.241581
# Item 84409     0.262908
# Item 78445     0.271785
# Item 63808     0.274567
# Item 111696    0.301232
# Item 83994     0.308385
# Item 42803     0.314121
# Item 30740     0.319364
# Item 54448     0.338186
# Item 63187     0.340392
# Item 117743    0.342064
# Item 30570     0.342870
# Item 83792     0.345410
# ...

# %%
plot_item_compar(bin_reg, comp, item = 'Item 30436')

# %% [markdown]
# ## 4. Linguagens e Códigos

# %%
comp = 'LC'

item_ing = ['Item 55166', 'Item 54110', 'Item 23564', 'Item 31954', 'Item 118180']
item_esp = ['Item 96705', 'Item 118222','Item 39016', 'Item 118167', 'Item 48558']

df_reg = get_df_reg(comp, ano)
df_reg_ing = {}
df_reg_esp = {}
df_reg_pt = {}

for reg in df_reg.keys():
    df_reg_ing[reg] = df_reg[reg][df_reg[reg]['TP_LINGUA']==0][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_reg_esp[reg] = df_reg[reg][df_reg[reg]['TP_LINGUA']==1][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_reg_pt[reg] = df_reg[reg][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    
    for col in df_reg['N'].columns:
        if col in item_ing:
            df_reg_ing[reg][col] = df_reg[reg][df_reg[reg]['TP_LINGUA']==0][col]
        elif col in item_esp:
            df_reg_esp[reg][col] = df_reg[reg][df_reg[reg]['TP_LINGUA']==1][col]
        elif col!='NU_INSCRICAO' and col!='NU_NOTA_LC' and col!='TP_LINGUA':
            df_reg_pt[reg][col] = df_reg[reg][col]

# %%
print('Média e Std para Inglês:')
print_mean_std(df_reg_ing, comp)
# Out:
# Média e Std para Inglês:
# N - Média: 510.67;   Std: 66.99
# NE - Média: 520.72;   Std: 68.02
# SE - Média: 543.36;   Std: 58.74
# S - Média: 545.71;   Std: 56.85
# CO - Média: 540.51;   Std: 61.26
# Geral - Média: 535.69;   Std: 62.79

# %%
print('Média e Std para Espanhol:')
print_mean_std(df_reg_esp, comp)
# Out:
# Média e Std para Espanhol:
# N - Média: 487.58;   Std: 61.21
# NE - Média: 489.76;   Std: 62.41
# SE - Média: 512.93;   Std: 56.80
# S - Média: 514.08;   Std: 54.55
# CO - Média: 506.42;   Std: 57.82
# Geral - Média: 500.14;   Std: 60.59

# %%
print('Média e Std total:')
print_mean_std(df_reg_pt, comp)
# Out:
# Média e Std total:
# N - Média: 497.13;   Std: 64.67
# NE - Média: 502.61;   Std: 66.57
# SE - Média: 533.56;   Std: 59.84
# S - Média: 532.46;   Std: 58.04
# CO - Média: 521.99;   Std: 61.80
# Geral - Média: 519.36;   Std: 64.28

# %%
plot_hist_scores(df_reg_pt, comp)

# %% [markdown]
# ### 4.1 Inglês

# %%
print("Proporção de participantes em inglês:")
for reg in df_reg.keys():
    print(f"{reg}: {1-df_reg[reg].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em inglês:
# N: 0.413
# NE: 0.415
# SE: 0.678
# S: 0.581
# CO: 0.457
# Geral: 0.541

# %%
plot_hist_scores(df_reg_ing, comp)

# %%
questoes_list = list(df_reg_ing['N'].columns[2:])

bin_reg_ing = bin_scores(df_reg_ing, comp, questoes_list, nota_min=300, nota_max=700, step=20)
auc_reg_ing = auc_regions(bin_reg_ing, questoes_list)

auc_reg_ing
# Out:
#                      N         NE         SE          S         CO      Geral
# Item 55166    9.528416   9.735481   9.984842  10.216084   9.809390   9.838314
# Item 54110    7.549943   7.683634   8.289484   8.485423   8.184984   8.062651
# Item 23564   10.065911   9.791430  10.641640  10.928410  10.387183  10.330331
# Item 31954   11.007769  11.188179  11.548486  11.512978  11.533872  11.363727
# Item 118180   7.745289   7.688120   8.398481   8.573477   8.346665   8.149826

# %%
sort_abs_auc_dif(auc_reg_ing)
# Out:
# Item 31954     0.360306
# Item 55166     0.406694
# Item 54110     0.605850
# Item 118180    0.710360
# Item 23564     0.850210
# dtype: float64

# %%
plot_item_compar(bin_reg_ing, comp, item = 'Item 23564')

# %% [markdown]
# ### 4.2 Espanhol

# %%
print("Proporção de participantes em espanhol:")
for reg in df_reg.keys():
    print(f"{reg}: {df_reg[reg].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em espanhol:
# N: 0.587
# NE: 0.585
# SE: 0.322
# S: 0.419
# CO: 0.543
# Geral: 0.459

# %%
plot_hist_scores(df_reg_esp, comp)

# %%
questoes_list = list(df_reg_esp['N'].columns[2:])

bin_reg_esp = bin_scores(df_reg_esp, comp, questoes_list, nota_min=300, nota_max=700, step=20)
auc_reg_esp = auc_regions(bin_reg_esp, questoes_list)

auc_reg_esp
# Out:
#                     N        NE        SE          S        CO     Geral
# Item 96705   6.733624  6.746922  6.600894   6.472649  6.778446  6.654862
# Item 118222  9.652889  9.511445  9.736925  10.218171  9.784241  9.671395
# Item 39016   6.260617  6.226948  6.274720   6.569711  6.464731  6.324390
# Item 118167  7.851015  7.847173  7.948669   7.870275  7.841398  7.870127
# Item 48558   6.859488  6.761189  7.044576   6.971843  6.900725  6.859947

# %%
sort_abs_auc_dif(auc_reg_esp)
# Out:
# Item 118167    0.101496
# Item 48558     0.283386
# Item 39016     0.294991
# Item 96705     0.305797
# Item 118222    0.481245
# dtype: float64

# %%
plot_item_compar(bin_reg_esp, comp, item = 'Item 118222')

# %% [markdown]
# ### 4.3 Português

# %%
questoes_list = list(df_reg_pt['N'].columns[2:])

bin_reg_pt = bin_scores(df_reg_pt, comp, questoes_list, nota_min=300, nota_max=700, step=20)
auc_reg_pt = auc_regions(bin_reg_pt, questoes_list)

auc_reg_pt
# Out:
#                      N         NE         SE          S         CO      Geral
# Item 86563    6.250081   6.256128   5.863703   5.773363   5.941838   5.994980
# Item 118161   9.249956   9.463885   9.209889   8.982983   9.265537   9.274164
# Item 118147   9.611284   9.652679   9.567161   9.652417   9.806340   9.637900
# Item 118118   7.668743   7.504703   7.707363   7.985382   7.732408   7.686311
# Item 118215   6.423235   6.370719   6.243473   6.132901   6.358558   6.271835
# Item 118207   6.329608   6.595041   6.249324   6.246099   6.342590   6.369027
# Item 118170   7.276260   7.009289   6.616869   6.962754   6.867281   6.820876
# Item 90165    6.257170   6.322488   6.497582   6.671994   6.471742   6.436861
# Item 118232   5.230540   5.305744   4.987589   5.146648   4.941382   5.151149
# Item 118174   7.183503   7.227082   7.065758   6.880738   7.128860   7.095733
# Item 76167    7.899768   7.884116   7.987458   7.931659   7.928997   7.936120
# ...

# %%
sort_abs_auc_dif(auc_reg_pt)
# Out:
# Item 81992     0.063744
# Item 118264    0.071127
# Item 118103    0.072477
# Item 76167     0.103342
# Item 86496     0.126052
# Item 118276    0.140795
# Item 59976     0.143144
# Item 23833     0.145016
# Item 118260    0.161381
# Item 118147    0.168441
# Item 118256    0.188786
# Item 118306    0.190428
# Item 68624     0.190513
# Item 86932     0.197716
# Item 90165     0.200252
# Item 24785     0.213101
# Item 118215    0.225657
# Item 118117    0.226899
# Item 32261     0.233488
# Item 118174    0.248122
# Item 96525     0.252543
# Item 118118    0.278020
# Item 118161    0.282554
# Item 89550     0.305192
# Item 77356     0.308274
# Item 118232    0.318155
# Item 118028    0.321420
# Item 89317     0.322072
# Item 118165    0.329834
# Item 118207    0.345717
# Item 14169     0.390269
# Item 118170    0.392420
# Item 86563     0.392426
# Item 118192    0.399331
# Item 118134    0.408160
# Item 118246    0.445273
# Item 118299    0.465280
# Item 118235    0.494957
# ...

# %%
plot_item_compar(bin_reg_pt, comp, item = 'Item 89874')
