# %% [markdown]
# # Compare Races - ENEM 2019

# %%
import pandas as pd
from CompareGroupsFunctions import *

ano = '2019'

# %% [markdown]
# ## 1. Ciências Humanas

# %%
ch_comp = GroupComparator(comp='CH', ano=ano, gps=[0, 1, 2, 3])
df_gp = ch_comp.get_df_gp()
ch_comp.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 501.29;   Std: 85.44
# Branca - Média: 528.63;   Std: 80.63
# Preta - Média: 489.77;   Std: 76.12
# Parda - Média: 490.48;   Std: 77.67
# Geral - Média: 506.10;   Std: 81.10

# %%
ch_comp.plot_hist_scores()

# %%
bin_ch = ch_comp.bin_scores()
auc_ch = ch_comp.auc_groups()

auc_ch
# Out:
#                      0          1          2          3      Geral
# Item 111894   8.456833   8.413128   8.039221   8.256041   8.323319
# Item 118054   6.697024   6.430764   6.404949   6.405454   6.405959
# Item 118067   3.714249   3.755311   3.807709   3.796328   3.804108
# Item 66498   10.720069  10.797638  10.499246  10.650190  10.709633
# Item 86751    5.271927   5.196519   5.343961   5.185812   5.215511
# Item 83820   12.960104  13.008328  13.042882  13.081282  13.042855
# Item 77940   13.516326  13.297503  13.336830  13.485711  13.425185
# Item 118034   9.531966   9.548191   9.322046   9.243860   9.423033
# Item 84888    7.700585   7.405525   7.246320   7.392412   7.436304
# Item 88233    7.276898   7.370825   7.325230   7.139956   7.301009
# Item 86934    8.302087   8.702292   8.205438   8.465712   8.617787
# Item 118158  11.434102  11.629007  11.509097  11.386005  11.493840
# Item 88306    8.813744   8.970768   8.979833   8.846263   8.893131
# Item 118033  12.719151  12.870418  12.604411  12.739789  12.766398
# Item 84769    8.616946   8.578841   8.449270   8.509850   8.548332
# Item 118022   9.226106   9.198280   9.265178   9.260914   9.222810
# Item 111844  11.580942  11.420857  11.748402  11.503110  11.488048
# Item 33960    8.433291   8.446793   8.603825   8.431753   8.472548
# Item 78903   12.890637  13.149645  12.980637  13.067732  13.057548
# Item 97975    9.158759   8.904596   8.786442   8.772667   8.874162
# Item 118108  12.084356  12.249624  12.250695  12.204239  12.223713
# Item 66219    9.444510   9.051325   9.530322   9.549532   9.318150
# Item 111877  10.436244  10.508457  10.550115  10.480802  10.502283
# Item 88194    6.107610   5.993790   5.911308   6.041346   6.021324
# Item 118125   8.410237   8.607620   8.939307   8.564153   8.547308
# Item 87057   12.071481  12.035608  12.256039  12.275423  12.100444
# Item 85139   11.500618  11.640974  11.791669  11.668096  11.651355
# Item 88308    7.777357   7.729368   8.119590   7.870092   7.807052
# Item 87709    7.351772   7.392180   7.635169   7.506114   7.461775
# Item 112135  12.483188  12.584387  12.575652  12.617123  12.580544
# Item 81689    5.802102   5.635986   5.927851   5.772998   5.731342
# Item 118029   9.760816   9.726714   9.802300   9.712315   9.728182
# Item 118024   5.140360   5.105767   5.135146   5.200170   5.164700
# Item 97013    7.506888   7.440838   7.714428   7.493052   7.455737
# Item 11601    8.636439   8.551413   8.401886   8.675091   8.591880
# Item 89147    8.289795   8.708442   8.325680   8.382862   8.550489
# Item 84811   11.822983  11.548544  11.853298  11.835570  11.717118
# Item 96447   11.096984  11.159698  11.018359  10.973615  11.039218
# Item 96302   10.310028  10.420734  10.513128  10.457484  10.441240
# Item 111820   3.688020   3.609276   3.643680   3.744701   3.654428
# Item 96596    6.619345   6.293376   6.168650   6.319168   6.352721
# Item 84147   11.992782  11.762435  11.995062  12.031093  11.913808
# Item 95648    8.842443   8.957033   8.896802   9.024579   8.945775
# Item 118038   9.290210   9.452359   9.001457   9.250716   9.363845
# Item 76955   13.261136  13.568357  13.632984  13.481274  13.509918

# %%
sorted_auc_dif_ch = ch_comp.sort_abs_auc_dif()
# Out:
# Item 83820     0.048224
# Item 118067    0.052398
# Item 118024    0.065024
# Item 118022    0.066897
# Item 111877    0.072213
# Item 118029    0.089984
# Item 111820    0.101022
# Item 112135    0.101199
# Item 96302     0.110706
# Item 95648     0.127778
# Item 84769     0.129570
# Item 88194     0.130039
# Item 96447     0.141339
# Item 85139     0.150695
# Item 88306     0.157025
# Item 86751     0.158149
# Item 118108    0.165268
# Item 33960     0.172072
# Item 88233     0.185274
# Item 118158    0.194904
# Item 77940     0.218823
# Item 87057     0.220431
# Item 118034    0.226145
# Item 84147     0.232627
# Item 87709     0.242989
# Item 97975     0.254163
# Item 78903     0.259008
# Item 118033    0.266007
# Item 118054    0.266260
# Item 11601     0.273206
# Item 97013     0.273590
# Item 81689     0.291865
# Item 84888     0.295060
# Item 66498     0.298392
# Item 84811     0.304754
# Item 76955     0.307222
# Item 96596     0.325970
# Item 111844    0.327545
# Item 111894    0.373907
# Item 118125    0.375154
# Item 88308     0.390222
# Item 89147     0.418647
# Item 118038    0.450902
# Item 66219     0.478998
# Item 86934     0.496854
# dtype: float64

# %%
ch_comp.plot_item_compar(item = 'Item 86934')

# %% [markdown]
# ## 2. Ciências da Natureza

# %%
cn_comp = GroupComparator(comp='CN', ano=ano, gps=[0, 1, 2, 3])
df_gp = cn_comp.get_df_gp()
cn_comp.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 474.25;   Std: 79.16
# Branca - Média: 497.76;   Std: 78.52
# Preta - Média: 458.72;   Std: 66.93
# Parda - Média: 461.87;   Std: 70.17
# Geral - Média: 476.48;   Std: 75.76

# %%
cn_comp.plot_hist_scores()

# %%
bin_cn = cn_comp.bin_scores()
auc_cn = cn_comp.auc_groups()

auc_cn
# Out:
#                      0          1          2          3      Geral
# Item 82364    8.668539   8.784887   8.935238   8.669058   8.735879
# Item 117836   5.985534   5.657500   5.797342   6.108915   5.779421
# Item 29776   13.292752  13.166574  13.062439  13.091422  13.132936
# Item 117999  11.220051  11.410396  11.185618  11.054071  11.227275
# Item 117746   4.099362   4.534453   3.934713   4.501253   4.525638
# Item 86521   11.927322  12.085760  11.803327  12.010383  12.041663
# Item 31718   12.161346  12.007158  11.956203  12.042903  12.057190
# Item 89150   12.272716  12.462558  12.085767  12.211918  12.313530
# Item 117988   8.980897   8.793284   9.081219   8.958478   8.864233
# Item 7529    12.207889  12.160474  12.442243  12.295711  12.246442
# Item 88853   10.157858  10.289660  10.276342  10.269363  10.291538
# Item 117883   5.807775   5.758457   5.649568   5.613893   5.703744
# Item 82490    9.809611  10.210456   9.945793   9.836431  10.047168
# Item 111624  11.345527  11.281668  11.602256  11.266641  11.276743
# Item 82236    7.413817   7.262138   7.237598   7.342500   7.287914
# Item 83441    4.468273   4.050419   4.186117   4.076244   4.121722
# Item 19223   12.916974  12.791110  12.939061  12.823107  12.825710
# Item 78504    6.090492   6.066337   6.042810   6.128752   6.098385
# Item 7629     6.965110   6.874425   6.578291   6.996854   6.920952
# Item 14273    3.522705   3.387361   3.189418   3.157247   3.366757
# Item 97169    4.072171   3.889151   3.739541   3.906477   3.935700
# Item 49600    4.817382   4.695914   4.860741   4.799120   4.723142
# Item 96556    7.725554   7.696081   7.751066   7.751881   7.731930
# Item 39290    9.436439   9.485287   9.700268   9.693309   9.580484
# Item 89298   10.020159  10.262275   9.894298  10.092709  10.224481
# Item 55328    8.830070   8.562784   8.569048   8.936486   8.726374
# Item 89515    8.648854   8.825246   8.704356   8.673155   8.760577
# Item 117868  10.781055  10.529412  10.350347  10.618011  10.559695
# Item 117890   8.446349   8.461521   8.144037   8.343510   8.414756
# Item 54381    3.019390   2.863737   3.310568   3.116435   2.930329
# Item 117979   7.525586   7.919707   7.694850   7.713156   7.826343
# Item 83609    4.961652   5.116825   4.997235   4.995879   5.021840
# Item 60311   12.329409  12.499761  12.464579  12.648177  12.550812
# Item 81478    7.289453   7.423134   7.158600   7.349630   7.409974
# Item 83526    6.482745   6.602128   6.330473   6.464131   6.540451
# Item 111601   4.897101   4.831209   4.885128   4.765364   4.798520
# Item 111545   5.846541   5.790927   6.012126   5.824868   5.817348
# Item 19407    6.308105   6.116812   6.137823   6.230699   6.148634
# Item 89772    6.330192   6.543695   5.795630   6.143230   6.395054
# Item 24104    8.328518   8.202034   8.206053   8.177606   8.240853
# Item 111705   7.097979   6.900786   6.442840   6.840260   6.880412
# Item 117875   5.922904   6.363240   6.296034   6.467114   6.368749
# Item 117642   9.692645   9.463586   9.761484   9.483902   9.478159
# Item 85548    9.338764   9.204726   9.634681   9.551798   9.301766
# Item 84568    8.434598   8.215565   8.459512   8.085972   8.146435

# %%
sorted_auc_dif_cn = cn_comp.sort_abs_auc_dif()
# Out:
# Item 96556     0.054985
# Item 78504     0.085943
# Item 117883    0.108889
# Item 111601    0.119764
# Item 29776     0.126178
# Item 24104     0.126484
# Item 88853     0.131801
# Item 19223     0.147951
# Item 82236     0.151680
# Item 31718     0.154188
# Item 83609     0.155173
# Item 49600     0.164827
# Item 89515     0.176393
# Item 97169     0.183020
# Item 60311     0.183598
# Item 19407     0.191293
# Item 14273     0.209510
# Item 39290     0.214980
# Item 111545    0.221199
# Item 117999    0.224778
# Item 81478     0.264533
# Item 82364     0.266180
# Item 117868    0.267664
# Item 83526     0.271655
# Item 7529      0.281770
# Item 86521     0.282433
# Item 117988    0.287935
# Item 117642    0.297897
# Item 117890    0.317484
# Item 117836    0.329494
# Item 111624    0.335615
# Item 55328     0.367438
# Item 89298     0.367977
# Item 84568     0.373540
# Item 89150     0.376792
# Item 117979    0.394121
# Item 82490     0.400845
# Item 83441     0.417854
# Item 7629      0.418563
# Item 85548     0.429955
# Item 117875    0.440336
# Item 54381     0.446831
# Item 111705    0.457947
# Item 117746    0.599740
# Item 89772     0.748065
# dtype: float64

# %%
cn_comp.plot_item_compar(item = 'Item 89772')

# %%
cn_comp.plot_item_compar(item = 'Item 117746')

# %% [markdown]
# ## 3. Matemática

# %%
mt_comp = GroupComparator(comp='MT', ano=ano, gps=[0, 1, 2, 3])
df_gp = mt_comp.get_df_gp()
mt_comp.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 522.73;   Std: 112.23
# Branca - Média: 559.76;   Std: 115.86
# Preta - Média: 496.98;   Std: 90.51
# Parda - Média: 506.38;   Std: 97.97
# Geral - Média: 527.62;   Std: 108.81

# %%
mt_comp.plot_hist_scores()

# %%
bin_mt = mt_comp.bin_scores(nota_min=300, nota_max=800)
auc_mt = mt_comp.auc_groups()
sorted_auc_dif_mt = mt_comp.sort_abs_auc_dif()
# Out:
# Item 83955     0.036979
# Item 14324     0.053818
# Item 10360     0.072549
# Item 117607    0.077139
# Item 28434     0.079019
# Item 83754     0.082156
# Item 117798    0.086654
# Item 63187     0.098974
# Item 78445     0.101078
# Item 9779      0.109201
# Item 17642     0.110136
# Item 13303     0.121737
# Item 117783    0.121854
# Item 8401      0.124160
# Item 117818    0.126672
# Item 117612    0.127015
# Item 84374     0.131036
# Item 89634     0.135664
# Item 117743    0.136264
# Item 117845    0.142323
# Item 86432     0.149027
# Item 83792     0.152855
# Item 39708     0.159735
# Item 111593    0.166242
# Item 117950    0.169437
# Item 111608    0.169712
# Item 23065     0.171882
# Item 63808     0.173244
# Item 111518    0.184834
# Item 117726    0.187343
# Item 54448     0.200269
# Item 117725    0.202768
# Item 30570     0.207905
# Item 111696    0.211452
# Item 30436     0.217271
# Item 84409     0.237668
# Item 8442      0.269882
# Item 117767    0.271261
# Item 31184     0.308357
# Item 18002     0.310145
# Item 30740     0.334753
# Item 42803     0.365549
# Item 8368      0.371179
# Item 83994     0.453882
# Item 117635    0.479309
# dtype: float64

# %%
mt_comp.plot_item_compar(item = 'Item 83994')

# %% [markdown]
# ## 4. Linguagens e Códigos

# %%
comp = 'LC'

lc_comp = GroupComparator(comp=comp, ano=ano, gps=[0, 1, 2, 3])
df_gp = lc_comp.get_df_gp()

item_ing = ['Item 55166', 'Item 54110', 'Item 23564', 'Item 31954', 'Item 118180']
item_esp = ['Item 96705', 'Item 118222','Item 39016', 'Item 118167', 'Item 48558']

df_gp_ing = {}
df_gp_esp = {}
df_gp_pt = {}

for g in df_gp.keys():
    df_gp_ing[g] = df_gp[g][df_gp[g]['TP_LINGUA']==0][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_esp[g] = df_gp[g][df_gp[g]['TP_LINGUA']==1][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_pt[g] = df_gp[g][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    
    for col in df_gp[0].columns:
        if col in item_ing:
            df_gp_ing[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==0][col]
        elif col in item_esp:
            df_gp_esp[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==1][col]
        elif col!='NU_INSCRICAO' and col!='NU_NOTA_LC' and col!='TP_LINGUA':
            df_gp_pt[g][col] = df_gp[g][col]

# %% [markdown]
# ### 4.1 Inglês

# %%
print("Proporção de participantes em inglês:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em inglês:
# ND: 0.522
# Branca: 0.638
# Preta: 0.498
# Parda: 0.465
# Geral: 0.541

# %%
lc_comp_ing = GroupComparator(comp=comp, ano=ano, gps=[0, 1, 2, 3])
lc_comp_ing.df_gp = df_gp_ing
lc_comp_ing.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 532.23;   Std: 67.83
# Branca - Média: 551.42;   Std: 58.24
# Preta - Média: 517.62;   Std: 61.88
# Parda - Média: 521.48;   Std: 63.32
# Geral - Média: 535.69;   Std: 62.79

# %%
lc_comp_ing.plot_hist_scores()

# %%
bin_lc_ing = lc_comp_ing.bin_scores(nota_min=350, nota_max=700)
auc_lc_ing = lc_comp_ing.auc_groups()
sorted_auc_dif_lc_ing = lc_comp_ing.sort_abs_auc_dif()
# Out:
# Item 31954     0.318522
# Item 54110     0.440630
# Item 55166     0.451526
# Item 118180    0.692487
# Item 23564     0.724162
# dtype: float64

# %%
lc_comp_ing.plot_item_compar(item = 'Item 23564')

# %% [markdown]
# ### 4.2 Espanhol

# %%
print("Proporção de participantes em espanhol:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em espanhol:
# ND: 0.478
# Branca: 0.362
# Preta: 0.502
# Parda: 0.535
# Geral: 0.459

# %%
lc_comp_esp = GroupComparator(comp=comp, ano=ano, gps=[0, 1, 2, 3])
lc_comp_esp.df_gp = df_gp_esp
lc_comp_esp.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 493.84;   Std: 62.86
# Branca - Média: 513.99;   Std: 57.92
# Preta - Média: 495.13;   Std: 59.93
# Parda - Média: 493.39;   Std: 60.87
# Geral - Média: 500.14;   Std: 60.59

# %%
lc_comp_esp.plot_hist_scores()

# %%
bin_lc_esp = lc_comp_esp.bin_scores(nota_min=350, nota_max=700)
auc_lc_esp = lc_comp_esp.auc_groups()
sorted_auc_dif_lc_esp = lc_comp_esp.sort_abs_auc_dif()
# Out:
# Item 96705     0.143725
# Item 118167    0.213211
# Item 118222    0.218836
# Item 39016     0.268765
# Item 48558     0.336768
# dtype: float64

# %%
lc_comp_esp.plot_item_compar(item = 'Item 48558')

# %% [markdown]
# ### 4.3 Português

# %%
lc_comp_pt = GroupComparator(comp=comp, ano=ano, gps=[0, 1, 2, 3])
lc_comp_pt.df_gp = df_gp_pt
lc_comp_pt.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 513.86;   Std: 68.25
# Branca - Média: 537.89;   Std: 60.84
# Preta - Média: 506.33;   Std: 61.94
# Parda - Média: 506.44;   Std: 63.58
# Geral - Média: 519.36;   Std: 64.28

# %%
lc_comp_pt.plot_hist_scores()

# %%
bin_lc_pt = lc_comp_pt.bin_scores(nota_min=350, nota_max=700)
auc_lc_pt = lc_comp_pt.auc_groups()
sorted_auc_dif_lc_pt = lc_comp_pt.sort_abs_auc_dif()
# Out:
# Item 59976     0.052528
# Item 14169     0.064629
# Item 118232    0.074184
# Item 24785     0.083688
# Item 118134    0.087467
# Item 89317     0.102786
# Item 89550     0.103074
# Item 118118    0.112121
# Item 77356     0.112787
# Item 76167     0.114100
# Item 23833     0.122490
# Item 118256    0.124716
# Item 118215    0.129266
# Item 118207    0.129670
# Item 118117    0.134437
# Item 118192    0.136225
# Item 118174    0.137472
# Item 118299    0.143654
# Item 118260    0.157234
# Item 118235    0.163871
# Item 86496     0.176576
# Item 81992     0.181484
# Item 89874     0.182151
# Item 90165     0.193921
# Item 86932     0.200818
# Item 68624     0.221608
# Item 118306    0.234892
# Item 96525     0.234953
# Item 32261     0.245249
# Item 118103    0.247365
# Item 118147    0.254194
# Item 118165    0.264729
# Item 118161    0.276128
# Item 118278    0.315076
# Item 118276    0.315790
# Item 118246    0.340393
# Item 118028    0.379109
# Item 86563     0.393790
# Item 118264    0.434441
# Item 118170    0.577979
# dtype: float64

# %%
lc_comp_pt.plot_item_compar(item = 'Item 118170')
