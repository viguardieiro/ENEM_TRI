# %% [markdown]
# # Compare Sex - ENEM 2018

# %%
import pandas as pd
from CompareGroupsFunctions import *

ano = '2018'

# %% [markdown]
# ## 1. Ciências Humanas

# %%
ch_comp = GroupComparator(comp='CH', ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
df_gp = ch_comp.get_df_gp()
ch_comp.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 568.33;   Std: 84.21
# Feminino - Média: 559.98;   Std: 78.80
# Geral - Média: 563.48;   Std: 81.21

# %%
ch_comp.plot_hist_scores_2groups()

# %%
bin_ch = ch_comp.bin_scores()
auc_ch = ch_comp.auc_groups()

auc_ch
# Out:
#                     M         F     Geral
# Item 84321   5.933684  5.629543  5.753403
# Item 111920  5.597845  5.111770  5.331202
# Item 112045  6.967643  7.137061  7.057272
# Item 97982   5.757750  5.794779  5.768840
# Item 111805  6.616684  6.505732  6.539666
# Item 96595   8.629539  9.293285  9.017687
# Item 86760   6.517261  6.760489  6.649977
# Item 111972  3.524852  3.367358  3.427196
# Item 44378   9.085854  8.884657  8.964089
# Item 83733   7.867774  7.528373  7.680244
# Item 96813   7.620594  6.858806  7.171134
# Item 97862   7.922469  7.630112  7.752509
# Item 97652   5.733344  5.587169  5.662777
# Item 111823  7.354158  7.409823  7.411234
# Item 97747   9.404215  9.573096  9.505460
# Item 95752   6.537176  6.414525  6.484791
# Item 111988  7.666655  7.718198  7.695773
# Item 89461   6.577693  5.828209  6.161796
# Item 88500   7.857728  8.218448  8.063409
# Item 112081  5.779592  5.458177  5.606900
# Item 97786   4.014392  4.656336  4.384784
# Item 88057   6.428119  5.724283  6.037818
# Item 87101   7.111754  7.533440  7.368606
# Item 98027   4.495910  4.373012  4.415634
# Item 85205   6.538737  7.053840  6.811312
# Item 111841  6.510281  6.795249  6.681532
# Item 111943  6.190731  5.939171  6.045944
# Item 96354   8.004913  7.086735  7.452873
# Item 112110  9.417633  9.687919  9.567260
# Item 112014  3.592988  3.566439  3.568758
# Item 86195   8.401915  9.016304  8.751168
# Item 88107   4.015646  4.004885  4.001564
# Item 97888   6.417829  6.682836  6.565566
# Item 84853   5.178165  5.128135  5.159140
# Item 95528   8.227971  8.254303  8.240720
# Item 111802  3.879911  4.096026  3.984703
# Item 111978  6.334007  5.751948  6.018923
# Item 87110   4.047919  3.675748  3.835935
# Item 89639   8.323401  8.514020  8.428378
# Item 26427   9.842855  9.532520  9.656521
# Item 112013  6.926003  6.576095  6.726736
# Item 111873  9.711495  9.835073  9.790162
# Item 88520   6.121319  6.142459  6.129651
# Item 112122  5.081617  4.969984  5.030753
# Item 89113   5.423540  5.787129  5.637691

# %%
sorted_auc_dif_ch = ch_comp.sort_abs_auc_dif()
# Out:
# Item 88107     0.010761
# Item 88520     0.021141
# Item 95528     0.026332
# Item 112014    0.026549
# Item 97982     0.037029
# Item 84853     0.050030
# Item 111988    0.051542
# Item 111823    0.055665
# Item 111805    0.110952
# Item 112122    0.111634
# Item 95752     0.122651
# Item 98027     0.122899
# Item 111873    0.123578
# Item 97652     0.146174
# Item 111972    0.157494
# Item 97747     0.168881
# Item 112045    0.169418
# Item 89639     0.190618
# Item 44378     0.201197
# Item 111802    0.216116
# Item 86760     0.243228
# Item 111943    0.251560
# Item 97888     0.265007
# Item 112110    0.270286
# Item 111841    0.284968
# Item 97862     0.292357
# Item 84321     0.304141
# Item 26427     0.310335
# Item 112081    0.321414
# Item 83733     0.339401
# Item 112013    0.349908
# Item 88500     0.360720
# Item 89113     0.363588
# Item 87110     0.372171
# Item 87101     0.421685
# Item 111920    0.486075
# Item 85205     0.515103
# Item 111978    0.582059
# Item 86195     0.614389
# Item 97786     0.641944
# Item 96595     0.663747
# Item 88057     0.703836
# Item 89461     0.749484
# Item 96813     0.761788
# Item 96354     0.918178
# dtype: float64

# %%
ch_comp.plot_item_compar(item = 'Item 96354')

# %% [markdown]
# ## 2. Ciências da Natureza

# %%
cn_comp = GroupComparator(comp='CN', ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
df_gp = cn_comp.get_df_gp()
cn_comp.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 499.94;   Std: 77.65
# Feminino - Média: 488.21;   Std: 71.94
# Geral - Média: 493.13;   Std: 74.62

# %%
cn_comp.plot_hist_scores_2groups()

# %%
bin_cn = cn_comp.bin_scores()
auc_cn = cn_comp.auc_groups()

auc_cn
# Out:
#                      M          F      Geral
# Item 111456   6.030151   6.397379   6.219685
# Item 87205    6.703731   5.697784   6.188762
# Item 39342    9.258893   9.586797   9.398572
# Item 111635   6.751842   7.211261   6.948477
# Item 111630   6.685675   5.692723   6.200239
# Item 61264    6.628361   7.567200   7.100195
# Item 11526   10.913151  10.950172  10.938138
# Item 111506   8.176825   7.937560   8.007798
# Item 111408   6.772300   6.299000   6.563108
# Item 66646   11.632563  11.468940  11.544985
# Item 12591    6.569496   6.344129   6.436350
# Item 67958    5.923346   6.129865   6.005667
# Item 82306    7.247034   6.710378   6.961179
# Item 60359    3.569686   3.017377   3.314775
# Item 111394   5.580821   6.181837   5.920844
# Item 62499    7.847863   7.661439   7.724614
# Item 88496    5.533753   5.884196   5.697358
# Item 43554    6.794062   6.970070   6.898275
# Item 76029    6.781371   7.309394   7.064817
# Item 111533   4.384649   4.831385   4.561722
# Item 87724    6.917586   7.130176   7.025497
# Item 89518    7.377841   6.685413   7.034407
# Item 111653  10.714576  11.052211  10.883471
# Item 59858    5.796821   6.210321   5.995413
# Item 86222   11.075237  11.275566  11.185432
# Item 76034    4.272177   3.480374   3.903922
# Item 82909    9.871177  10.241563  10.052955
# Item 12199    7.523910   6.310528   6.922801
# Item 111720   7.306920   7.819764   7.536858
# Item 111395   4.459950   4.916589   4.730201
# Item 111414   7.369071   8.392674   7.873387
# Item 111761   6.917934   5.328746   6.200810
# Item 111637   2.824669   2.974613   3.023365
# Item 111612   5.460859   6.059581   5.774528
# Item 111463   6.635855   6.409712   6.524770
# Item 111411  10.073400  10.495714  10.300758
# Item 97446    8.691768   9.343271   9.016633
# Item 111564   3.659542   4.540744   4.112456
# Item 27417    6.519660   6.828750   6.721607
# Item 40203    4.445023   4.395052   4.419753
# Item 17449    6.892751   6.580256   6.733619
# Item 46621    9.015942   9.034754   9.008703
# Item 85700    6.798610   7.014270   6.875513
# Item 83440    4.137996   3.424166   3.799877
# Item 62289    4.819812   4.843039   4.820223

# %%
sorted_auc_dif_cn = cn_comp.sort_abs_auc_dif()
# Out:
# Item 62289     0.023227
# Item 46621     0.026050
# Item 11526     0.037022
# Item 40203     0.049971
# Item 111637    0.149944
# Item 66646     0.163623
# Item 43554     0.176008
# Item 62499     0.186425
# Item 86222     0.200329
# Item 67958     0.206519
# Item 87724     0.212590
# Item 85700     0.215660
# Item 12591     0.225367
# Item 111463    0.226142
# Item 111506    0.239266
# Item 27417     0.309090
# Item 17449     0.312496
# Item 39342     0.327903
# Item 111653    0.337635
# Item 88496     0.350444
# Item 111456    0.367228
# Item 82909     0.370385
# Item 59858     0.413500
# Item 111411    0.422314
# Item 111533    0.446737
# Item 111395    0.456639
# Item 111635    0.459419
# Item 111408    0.473300
# Item 111720    0.512844
# Item 76029     0.528024
# Item 82306     0.536656
# Item 60359     0.552309
# Item 111612    0.598722
# Item 111394    0.601016
# Item 97446     0.651503
# Item 89518     0.692428
# Item 83440     0.713830
# Item 76034     0.791802
# Item 111564    0.881202
# Item 61264     0.938838
# Item 111630    0.992952
# Item 87205     1.005948
# Item 111414    1.023603
# Item 12199     1.213382
# Item 111761    1.589189
# dtype: float64

# %%
cn_comp.plot_item_compar(item = 'Item 111761')

# %%
cn_comp.plot_item_compar(item = 'Item 12199')

# %%
cn_comp.plot_item_compar(item = 'Item 111414')

# %%
cn_comp.plot_item_compar(item = 'Item 87205')

# %% [markdown]
# ## 3. Matemática

# %%
mt_comp = GroupComparator(comp='MT', ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
df_gp = mt_comp.get_df_gp()
mt_comp.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 560.95;   Std: 108.74
# Feminino - Média: 519.78;   Std: 94.89
# Geral - Média: 537.05;   Std: 102.96

# %%
mt_comp.plot_hist_scores_2groups()

# %%
bin_mt = mt_comp.bin_scores(nota_min=300, nota_max=800)
auc_mt = mt_comp.auc_groups()
sorted_auc_dif_mt = mt_comp.sort_abs_auc_dif()
# Out:
# Item 86027     0.026982
# Item 84768     0.063105
# Item 18456     0.067193
# Item 111477    0.068446
# Item 111557    0.093670
# Item 12922     0.128219
# Item 82123     0.155948
# Item 111523    0.160980
# Item 111524    0.161036
# Item 29938     0.174007
# Item 98294     0.191338
# Item 111535    0.194031
# Item 111554    0.217829
# Item 111487    0.224099
# Item 111468    0.237193
# Item 111434    0.242387
# Item 32189     0.253757
# Item 32953     0.254827
# Item 86988     0.267825
# Item 15884     0.272227
# Item 85892     0.281248
# Item 97059     0.283453
# Item 5990      0.289585
# Item 48921     0.305840
# Item 96201     0.307611
# Item 111609    0.311467
# Item 28815     0.321168
# Item 111512    0.341596
# Item 15292     0.344981
# Item 83742     0.357156
# Item 111725    0.397893
# Item 111628    0.409579
# Item 29500     0.413809
# Item 98070     0.422692
# Item 82367     0.447653
# Item 66805     0.456262
# Item 111692    0.539944
# Item 30331     0.543766
# Item 32905     0.559603
# Item 61172     0.568712
# Item 53559     0.725412
# Item 111718    0.825555
# Item 111594    0.993594
# Item 62736     1.794979
# dtype: float64

# %%
mt_comp.plot_item_compar(item = 'Item 62736')

# %%
mt_comp.plot_item_compar(item = 'Item 111594')

# %%
mt_comp.plot_item_compar(item = 'Item 111718')

# %% [markdown]
# ## 4. Linguagens e Códigos

# %%
comp = 'LC'

lc_comp = GroupComparator(comp=comp, ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
df_gp = lc_comp.get_df_gp()

item_ing = ['Item 85387', 'Item 87507', 'Item 13652', 'Item 95804', 'Item 87035']
item_esp = ['Item 84836', 'Item 59531','Item 55925', 'Item 32893', 'Item 88480']

df_gp_ing = {}
df_gp_esp = {}
df_gp_pt = {}

for g in df_gp.keys():
    df_gp_ing[g] = df_gp[g][df_gp[g]['TP_LINGUA']==0][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_esp[g] = df_gp[g][df_gp[g]['TP_LINGUA']==1][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_pt[g] = df_gp[g][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    
    for col in df_gp[list(df_gp.keys())[0]].columns:
        if col in item_ing:
            df_gp_ing[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==0][col]
        elif col in item_esp:
            df_gp_esp[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==1][col]
        elif col!='NU_INSCRICAO' and col!='NU_NOTA_LC' and col!='TP_LINGUA':
            df_gp_pt[g][col] = df_gp[g][col]

# %% [markdown]
# ### 4.1 Inglês

# %%
print("Proporção de participantes em inglês:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em inglês:
# Masculino: 0.581
# Feminino: 0.500
# Geral: 0.534

# %%
lc_comp_ing = GroupComparator(comp=comp, ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
lc_comp_ing.df_gp = df_gp_ing
lc_comp_ing.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 543.54;   Std: 72.57
# Feminino - Média: 538.06;   Std: 74.02
# Geral - Média: 540.55;   Std: 73.41

# %%
lc_comp_ing.plot_hist_scores_2groups()

# %%
bin_lc_ing = lc_comp_ing.bin_scores(nota_min=350, nota_max=700)
auc_lc_ing = lc_comp_ing.auc_groups()
sorted_auc_dif_lc_ing = lc_comp_ing.sort_abs_auc_dif()
# Out:
# Item 95804    0.021815
# Item 85387    0.189369
# Item 87035    0.209987
# Item 13652    0.322417
# Item 87507    0.750815
# dtype: float64

# %%
lc_comp_ing.plot_item_compar(item = 'Item 87507')

# %% [markdown]
# ### 4.2 Espanhol

# %%
print("Proporção de participantes em espanhol:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em espanhol:
# Masculino: 0.419
# Feminino: 0.500
# Geral: 0.466

# %%
lc_comp_esp = GroupComparator(comp=comp, ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
lc_comp_esp.df_gp = df_gp_esp
lc_comp_esp.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 502.48;   Std: 68.60
# Feminino - Média: 504.88;   Std: 68.17
# Geral - Média: 503.98;   Std: 68.34

# %%
lc_comp_esp.plot_hist_scores_2groups()

# %%
bin_lc_esp = lc_comp_esp.bin_scores(nota_min=350, nota_max=700)
auc_lc_esp = lc_comp_esp.auc_groups()
sorted_auc_dif_lc_esp = lc_comp_esp.sort_abs_auc_dif()
# Out:
# Item 55925    0.119184
# Item 88480    0.132539
# Item 32893    0.220079
# Item 84836    0.314145
# Item 59531    0.400266
# dtype: float64

# %%
lc_comp_esp.plot_item_compar(item = 'Item 59531')

# %% [markdown]
# ### 4.3 Português

# %%
lc_comp_pt = GroupComparator(comp=comp, ano=ano, gp_feat='TP_SEXO', gp_name='sexo', 
                               gp_map={'M':'Masculino', 'F': 'Feminino'})
lc_comp_pt.df_gp = df_gp_pt
lc_comp_pt.print_mean_std()
# Out:
# Média e Std por sexo:
# Masculino - Média: 526.36;   Std: 73.77
# Feminino - Média: 521.46;   Std: 73.06
# Geral - Média: 523.51;   Std: 73.40

# %%
lc_comp_pt.plot_hist_scores_2groups()

# %%
bin_lc_pt = lc_comp_pt.bin_scores(nota_min=350, nota_max=700)
auc_lc_pt = lc_comp_pt.auc_groups()
sorted_auc_dif_lc_pt = lc_comp_pt.sort_abs_auc_dif()
# Out:
# Item 89487     0.007676
# Item 97968     0.009109
# Item 112113    0.009519
# Item 112053    0.018455
# Item 111829    0.037609
# Item 64063     0.039087
# Item 78076     0.052726
# Item 8562      0.056374
# Item 23230     0.072780
# Item 112076    0.090833
# Item 111896    0.093641
# Item 96758     0.118758
# Item 9065      0.140005
# Item 23615     0.158030
# Item 112143    0.178616
# Item 89028     0.178764
# Item 82889     0.208828
# Item 23744     0.214256
# Item 112051    0.245336
# Item 24528     0.256246
# Item 25943     0.273215
# Item 97416     0.278838
# Item 97995     0.301270
# Item 6818      0.307453
# Item 83517     0.370543
# Item 112150    0.377281
# Item 112092    0.381654
# Item 112018    0.426272
# Item 76800     0.455747
# Item 111970    0.471555
# Item 111931    0.511296
# Item 112101    0.536577
# Item 111948    0.540048
# Item 112041    0.550818
# Item 112066    0.585030
# Item 89331     0.635582
# Item 68242     0.671665
# Item 112054    0.754911
# Item 111884    0.875349
# Item 24007     1.200552
# dtype: float64

# %%
lc_comp_pt.plot_item_compar(item = 'Item 24007')

# %%
lc_comp_pt.plot_item_compar(item = 'Item 111884')
