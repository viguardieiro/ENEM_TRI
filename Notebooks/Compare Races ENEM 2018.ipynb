# %% [markdown]
# # Compare Races - ENEM 2019

# %%
import pandas as pd
from CompareGroupsFunctions import *

ano = '2018'

# %% [markdown]
# ## 1. Ciências Humanas

# %%
ch_comp = GroupComparator(comp='CH', ano=ano, gps=[0, 1, 2, 3])
df_gp = ch_comp.get_df_gp()
ch_comp.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 565.33;   Std: 86.06
# Branca - Média: 583.70;   Std: 79.66
# Preta - Média: 550.20;   Std: 78.76
# Parda - Média: 549.67;   Std: 79.29
# Geral - Média: 563.48;   Std: 81.21

# %%
ch_comp.plot_hist_scores()

# %%
bin_ch = ch_comp.bin_scores()
auc_ch = ch_comp.auc_groups()

auc_ch
# Out:
#                     0         1         2         3     Geral
# Item 84321   5.818922  5.716401  5.866398  5.767455  5.753403
# Item 111920  5.428280  5.404993  5.349244  5.270574  5.331202
# Item 112045  7.028557  7.074106  7.029622  7.043006  7.057272
# Item 97982   5.717603  5.769200  5.832218  5.792328  5.768840
# Item 111805  6.600264  6.557849  6.856515  6.489618  6.539666
# Item 96595   8.884269  8.877210  8.955151  9.163750  9.017687
# Item 86760   6.682724  6.658228  6.686171  6.638860  6.649977
# Item 111972  3.570108  3.408576  3.275110  3.435342  3.427196
# Item 44378   8.940632  8.954753  8.915974  8.988514  8.964089
# Item 83733   7.632355  7.694420  7.680645  7.677173  7.680244
# Item 96813   7.117539  7.497001  6.837493  6.908921  7.171134
# Item 97862   7.799589  7.685022  8.066595  7.757377  7.752509
# Item 97652   5.667327  5.673218  5.637978  5.665716  5.662777
# Item 111823  7.350225  7.318222  7.554868  7.494877  7.411234
# Item 97747   9.435360  9.576934  9.409487  9.490908  9.505460
# Item 95752   6.531612  6.452600  6.425864  6.549758  6.484791
# Item 111988  7.503408  7.703184  7.691246  7.696870  7.695773
# Item 89461   6.135181  6.305044  5.925648  6.035547  6.161796
# Item 88500   8.021565  8.037444  8.151922  8.075376  8.063409
# Item 112081  5.596886  5.710789  5.557513  5.483145  5.606900
# Item 97786   4.405485  4.315132  4.486636  4.488269  4.384784
# Item 88057   6.040307  6.198153  5.672625  5.905749  6.037818
# Item 87101   7.470835  7.332832  7.389724  7.385964  7.368606
# Item 98027   4.555180  4.379671  4.326028  4.431952  4.415634
# Item 85205   6.833074  6.875606  6.758743  6.770480  6.811312
# Item 111841  6.780019  6.568225  6.945776  6.767379  6.681532
# Item 111943  6.060358  6.025074  6.080692  6.042383  6.045944
# Item 96354   7.507526  7.488861  7.491305  7.414842  7.452873
# Item 112110  9.493617  9.683122  9.532738  9.504857  9.567260
# Item 112014  3.593547  3.553558  3.451969  3.478950  3.568758
# Item 86195   8.760056  8.625285  8.795593  8.851924  8.751168
# Item 88107   3.825693  4.003463  4.042699  4.050322  4.001564
# Item 97888   6.573253  6.467201  6.542182  6.667545  6.565566
# Item 84853   5.290155  5.252897  5.069785  5.069836  5.159140
# Item 95528   8.162188  8.269496  8.181427  8.268470  8.240720
# Item 111802  4.019495  3.928422  4.094512  4.004376  3.984703
# Item 111978  6.027391  6.161611  5.823888  5.852335  6.018923
# Item 87110   3.921811  3.797206  3.827480  3.882797  3.835935
# Item 89639   8.363750  8.384036  8.541709  8.463754  8.428378
# Item 26427   9.693895  9.748568  9.493551  9.634662  9.656521
# Item 112013  6.790499  6.655978  6.894969  6.812866  6.726736
# Item 111873  9.771331  9.832400  9.802000  9.745168  9.790162
# Item 88520   6.176595  6.223585  5.946018  6.030145  6.129651
# Item 112122  4.968535  4.969319  5.203149  5.174250  5.030753
# Item 89113   5.737103  5.616895  5.470402  5.643800  5.637691

# %%
sorted_auc_dif_ch = ch_comp.sort_abs_auc_dif()
# Out:
# Item 97652     0.035239
# Item 112045    0.045549
# Item 86760     0.047310
# Item 111943    0.055619
# Item 111873    0.061069
# Item 83733     0.062065
# Item 97982     0.063018
# Item 44378     0.072540
# Item 96354     0.076463
# Item 111920    0.078670
# Item 112014    0.101589
# Item 95528     0.107308
# Item 88500     0.114479
# Item 85205     0.116862
# Item 95752     0.123894
# Item 87110     0.124605
# Item 97888     0.125363
# Item 87101     0.138003
# Item 84321     0.149997
# Item 112081    0.153277
# Item 89639     0.157673
# Item 111972    0.161531
# Item 111802    0.166090
# Item 97747     0.167446
# Item 86195     0.170308
# Item 97786     0.171504
# Item 89113     0.173398
# Item 98027     0.175509
# Item 88107     0.177770
# Item 84853     0.183112
# Item 112110    0.189505
# Item 111988    0.199776
# Item 96595     0.208599
# Item 112122    0.233829
# Item 111823    0.236646
# Item 112013    0.238992
# Item 26427     0.255016
# Item 88520     0.277567
# Item 111978    0.337723
# Item 111805    0.366897
# Item 111841    0.377551
# Item 89461     0.379396
# Item 97862     0.381573
# Item 88057     0.525528
# Item 96813     0.659508
# dtype: float64

# %%
ch_comp.plot_item_compar(item = 'Item 96813')

# %% [markdown]
# ## 2. Ciências da Natureza

# %%
cn_comp = GroupComparator(comp='CN', ano=ano, gps=[0, 1, 2, 3])
df_gp = cn_comp.get_df_gp()
cn_comp.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 497.72;   Std: 80.43
# Branca - Média: 512.89;   Std: 79.43
# Preta - Média: 477.10;   Std: 64.43
# Parda - Média: 479.93;   Std: 68.18
# Geral - Média: 493.13;   Std: 74.62

# %%
cn_comp.plot_hist_scores()

# %%
bin_cn = cn_comp.bin_scores()
auc_cn = cn_comp.auc_groups()

auc_cn
# Out:
#                      0          1          2          3      Geral
# Item 111456   6.020091   6.210040   6.227365   6.137749   6.219685
# Item 87205    6.116746   6.246760   6.119787   6.145536   6.188762
# Item 39342    9.089704   9.515218   9.413063   9.322039   9.398572
# Item 111635   7.132529   6.841044   7.299292   7.120954   6.948477
# Item 111630   6.346799   6.224848   5.977825   6.174185   6.200239
# Item 61264    7.260656   7.079528   7.288188   7.072395   7.100195
# Item 11526   10.914675  10.971214  10.901138  10.945155  10.938138
# Item 111506   8.004378   8.020779   7.920740   7.994862   8.007798
# Item 111408   6.815575   6.628704   6.516432   6.462706   6.563108
# Item 66646   11.684953  11.525115  11.654665  11.560366  11.544985
# Item 12591    6.535905   6.473948   6.437357   6.310903   6.436350
# Item 67958    5.977327   5.966379   6.190301   6.044917   6.005667
# Item 82306    6.939130   7.001836   6.834840   6.900902   6.961179
# Item 60359    3.478142   3.290823   3.257486   3.338038   3.314775
# Item 111394   5.972244   5.900196   6.001415   5.918196   5.920844
# Item 62499    7.795740   7.705264   7.800554   7.752793   7.724614
# Item 88496    5.743627   5.636755   5.692756   5.696739   5.697358
# Item 43554    6.803241   6.954382   6.787178   6.807379   6.898275
# Item 76029    7.106700   7.038882   7.225880   7.090740   7.064817
# Item 111533   4.615391   4.590220   4.514583   4.497032   4.561722
# Item 87724    7.201062   7.047948   6.753175   6.889415   7.025497
# Item 89518    7.092058   7.050372   6.866408   7.039795   7.034407
# Item 111653  10.880826  11.053672  10.797036  10.809920  10.883471
# Item 59858    5.902498   5.899266   6.136028   6.075108   5.995413
# Item 86222   10.953346  11.283725  11.172677  11.147182  11.185432
# Item 76034    3.961073   3.851926   3.998122   3.983842   3.903922
# Item 82909   10.100195  10.089163  10.113589   9.977891  10.052955
# Item 12199    6.988621   6.837457   6.988678   7.028171   6.922801
# Item 111720   7.414615   7.455618   7.668405   7.662066   7.536858
# Item 111395   4.685658   4.730381   4.599675   4.767542   4.730201
# Item 111414   7.944795   7.804169   7.922774   7.973932   7.873387
# Item 111761   6.594353   6.110565   6.166747   6.288715   6.200810
# Item 111637   3.300026   2.893580   3.040431   3.125119   3.023365
# Item 111612   5.822293   5.726181   5.620743   5.824257   5.774528
# Item 111463   6.537566   6.468100   6.546592   6.553894   6.524770
# Item 111411  10.174078  10.192723  10.325858  10.437358  10.300758
# Item 97446    8.818745   9.108803   8.713129   8.947808   9.016633
# Item 111564   3.918111   4.038498   4.213848   4.152177   4.112456
# Item 27417    6.778033   6.698434   6.721889   6.626104   6.721607
# Item 40203    4.470280   4.381050   4.318217   4.538896   4.419753
# Item 17449    6.649229   6.814103   6.569227   6.641032   6.733619
# Item 46621    8.924065   9.071814   8.867392   8.931710   9.008703
# Item 85700    6.913944   6.717830   7.052867   7.038525   6.875513
# Item 83440    4.016007   3.728518   3.939694   3.924706   3.799877
# Item 62289    4.785970   4.842032   4.782045   4.731572   4.820223

# %%
sorted_auc_dif_cn = cn_comp.sort_abs_auc_dif()
# Out:
# Item 11526     0.070076
# Item 111533    0.075638
# Item 111463    0.078492
# Item 62289     0.088651
# Item 62499     0.095290
# Item 27417     0.095785
# Item 111506    0.100038
# Item 111394    0.101218
# Item 88496     0.106872
# Item 12591     0.126454
# Item 87205     0.130015
# Item 82909     0.135698
# Item 111411    0.136600
# Item 111414    0.140625
# Item 76034     0.146196
# Item 12199     0.151221
# Item 66646     0.159838
# Item 82306     0.166997
# Item 43554     0.167203
# Item 111395    0.167866
# Item 111564    0.175350
# Item 89518     0.183964
# Item 111408    0.186872
# Item 76029     0.186997
# Item 60359     0.187319
# Item 111456    0.189949
# Item 111612    0.203514
# Item 46621     0.204422
# Item 111720    0.212786
# Item 61264     0.215794
# Item 40203     0.220679
# Item 67958     0.223922
# Item 59858     0.236762
# Item 17449     0.244876
# Item 111630    0.247022
# Item 111653    0.256636
# Item 83440     0.287489
# Item 87724     0.294773
# Item 86222     0.330380
# Item 85700     0.335037
# Item 97446     0.395674
# Item 111637    0.406446
# Item 39342     0.425514
# Item 111635    0.458249
# Item 111761    0.483788
# dtype: float64

# %%
cn_comp.plot_item_compar(item = 'Item 111761')

# %% [markdown]
# ## 3. Matemática

# %%
mt_comp = GroupComparator(comp='MT', ano=ano, gps=[0, 1, 2, 3])
df_gp = mt_comp.get_df_gp()
mt_comp.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 542.34;   Std: 109.68
# Branca - Média: 564.26;   Std: 110.61
# Preta - Média: 512.83;   Std: 87.50
# Parda - Média: 519.39;   Std: 93.41
# Geral - Média: 537.05;   Std: 102.96

# %%
mt_comp.plot_hist_scores()

# %%
bin_mt = mt_comp.bin_scores(nota_min=300, nota_max=800)
auc_mt = mt_comp.auc_groups()
sorted_auc_dif_mt = mt_comp.sort_abs_auc_dif()
# Out:
# Item 111477    0.066393
# Item 28815     0.079967
# Item 82123     0.083678
# Item 111557    0.087481
# Item 111487    0.090166
# Item 32189     0.091150
# Item 111434    0.093645
# Item 85892     0.098794
# Item 82367     0.101585
# Item 32953     0.111571
# Item 48921     0.111834
# Item 15884     0.115614
# Item 32905     0.120056
# Item 98070     0.121483
# Item 111535    0.122181
# Item 5990      0.122770
# Item 83742     0.125338
# Item 111594    0.127214
# Item 111725    0.129135
# Item 111554    0.134414
# Item 53559     0.137751
# Item 66805     0.141555
# Item 15292     0.146011
# Item 97059     0.148231
# Item 86988     0.156055
# Item 30331     0.159037
# Item 86027     0.166811
# Item 96201     0.168280
# Item 111468    0.168965
# Item 84768     0.170616
# Item 111512    0.176388
# Item 111692    0.179383
# Item 111609    0.188032
# Item 111524    0.212991
# Item 98294     0.213798
# Item 111718    0.223764
# Item 12922     0.251188
# Item 29500     0.253177
# Item 111523    0.271170
# Item 111628    0.301708
# Item 62736     0.332236
# Item 61172     0.346804
# Item 29938     0.358210
# Item 18456     0.414673
# dtype: float64

# %%
mt_comp.plot_item_compar(item = 'Item 29938')

# %%
mt_comp.plot_item_compar(item = 'Item 18456')

# %% [markdown]
# ## 4. Linguagens e Códigos

# %%
comp = 'LC'

lc_comp = GroupComparator(comp=comp, ano=ano, gps=[0, 1, 2, 3])
df_gp = lc_comp.get_df_gp()

item_ing = ['Item 85387', 'Item 87507', 'Item 13652', 'Item 95804', 'Item 87035']
item_esp = ['Item 84836', 'Item 59531','Item 55925', 'Item 32893', 'Item 88480']

df_gp_ing = {}
df_gp_esp = {}
df_gp_pt = {}

for g in df_gp.keys():
    df_gp_ing[g] = df_gp[g][df_gp[g]['TP_LINGUA']==0][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_esp[g] = df_gp[g][df_gp[g]['TP_LINGUA']==1][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    df_gp_pt[g] = df_gp[g][['NU_INSCRICAO','NU_NOTA_LC']].copy()
    
    for col in df_gp[0].columns:
        if col in item_ing:
            df_gp_ing[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==0][col]
        elif col in item_esp:
            df_gp_esp[g][col] = df_gp[g][df_gp[g]['TP_LINGUA']==1][col]
        elif col!='NU_INSCRICAO' and col!='NU_NOTA_LC' and col!='TP_LINGUA':
            df_gp_pt[g][col] = df_gp[g][col]

# %% [markdown]
# ### 4.1 Inglês

# %%
print("Proporção de participantes em inglês:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {1-df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em inglês:
# ND: 0.555
# Branca: 0.630
# Preta: 0.499
# Parda: 0.460
# Geral: 0.534

# %%
lc_comp_ing = GroupComparator(comp=comp, ano=ano, gps=[0, 1, 2, 3])
lc_comp_ing.df_gp = df_gp_ing
lc_comp_ing.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 544.63;   Std: 77.91
# Branca - Média: 558.14;   Std: 70.23
# Preta - Média: 521.68;   Std: 70.79
# Parda - Média: 525.00;   Std: 72.71
# Geral - Média: 540.55;   Std: 73.41

# %%
lc_comp_ing.plot_hist_scores()

# %%
bin_lc_ing = lc_comp_ing.bin_scores(nota_min=350, nota_max=700)
auc_lc_ing = lc_comp_ing.auc_groups()
sorted_auc_dif_lc_ing = lc_comp_ing.sort_abs_auc_dif()
# Out:
# Item 85387    0.190768
# Item 95804    0.221959
# Item 13652    0.298620
# Item 87507    0.572511
# Item 87035    0.751610
# dtype: float64

# %%
lc_comp_ing.plot_item_compar(item = 'Item 87035')

# %% [markdown]
# ### 4.2 Espanhol

# %%
print("Proporção de participantes em espanhol:")
for g in df_gp.keys():
    if g=='Geral':
        print(f"{g}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
    else:
        print(f"{lc_comp.gp_map[g]}: {df_gp[g].mean()['TP_LINGUA']:.3f}")
# Out:
# Proporção de participantes em espanhol:
# ND: 0.445
# Branca: 0.370
# Preta: 0.501
# Parda: 0.540
# Geral: 0.466

# %%
lc_comp_esp = GroupComparator(comp=comp, ano=ano, gps=[0, 1, 2, 3])
lc_comp_esp.df_gp = df_gp_esp
lc_comp_esp.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 499.58;   Std: 70.99
# Branca - Média: 518.44;   Std: 67.68
# Preta - Média: 500.12;   Std: 67.04
# Parda - Média: 496.77;   Std: 67.72
# Geral - Média: 503.98;   Std: 68.34

# %%
lc_comp_esp.plot_hist_scores()

# %%
bin_lc_esp = lc_comp_esp.bin_scores(nota_min=350, nota_max=700)
auc_lc_esp = lc_comp_esp.auc_groups()
sorted_auc_dif_lc_esp = lc_comp_esp.sort_abs_auc_dif()
# Out:
# Item 59531    0.139236
# Item 88480    0.163465
# Item 32893    0.205999
# Item 55925    0.270321
# Item 84836    0.323941
# dtype: float64

# %%
lc_comp_esp.plot_item_compar(item = 'Item 84836')

# %% [markdown]
# ### 4.3 Português

# %%
lc_comp_pt = GroupComparator(comp=comp, ano=ano, gps=[0, 1, 2, 3])
lc_comp_pt.df_gp = df_gp_pt
lc_comp_pt.print_mean_std()
# Out:
# Média e Std por raca:
# ND - Média: 524.58;   Std: 78.18
# Branca - Média: 543.46;   Std: 71.90
# Preta - Média: 510.87;   Std: 69.77
# Parda - Média: 509.75;   Std: 71.46
# Geral - Média: 523.51;   Std: 73.40

# %%
lc_comp_pt.plot_hist_scores()

# %%
bin_lc_pt = lc_comp_pt.bin_scores(nota_min=350, nota_max=700)
auc_lc_pt = lc_comp_pt.auc_groups()
sorted_auc_dif_lc_pt = lc_comp_pt.sort_abs_auc_dif()
# Out:
# Item 68242     0.054068
# Item 112053    0.073108
# Item 111970    0.090506
# Item 89331     0.091546
# Item 76800     0.093027
# Item 64063     0.105103
# Item 111948    0.106282
# Item 89487     0.107032
# Item 111931    0.110526
# Item 96758     0.114931
# Item 25943     0.115194
# Item 111829    0.122543
# Item 112113    0.130330
# Item 23615     0.133041
# Item 112066    0.146923
# Item 97416     0.150783
# Item 24007     0.154629
# Item 89028     0.156050
# Item 23744     0.156772
# Item 83517     0.161477
# Item 23230     0.169763
# Item 112051    0.174293
# Item 112041    0.181319
# Item 111884    0.181440
# Item 112101    0.186135
# Item 82889     0.187224
# Item 24528     0.187359
# Item 9065      0.192686
# Item 112054    0.219559
# Item 6818      0.223692
# Item 78076     0.244448
# Item 97995     0.272410
# Item 112018    0.298090
# Item 112150    0.324521
# Item 112092    0.369577
# Item 8562      0.373791
# Item 112143    0.375955
# Item 111896    0.407025
# Item 112076    0.423824
# Item 97968     0.628537
# dtype: float64

# %%
lc_comp_pt.plot_item_compar(item = 'Item 97968')
